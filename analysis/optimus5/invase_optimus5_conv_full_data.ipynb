# %%
import keras
import keras.backend as K
from keras.datasets import mnist
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv1D, MaxPooling1D, LSTM, ConvLSTM2D, GRU, BatchNormalization, LocallyConnected2D, Permute, TimeDistributed, Bidirectional
from keras.layers import Concatenate, Reshape, Conv2DTranspose, Embedding, Multiply, Activation

from functools import partial

from collections import defaultdict

import os
import pickle
import numpy as np

import scipy.sparse as sp
import scipy.io as spio

import isolearn.io as isoio
import isolearn.keras as isol

import matplotlib.pyplot as plt

from sequence_logo_helper import dna_letter_at, plot_dna_logo

from sklearn import preprocessing
import pandas as pd

import tensorflow as tf

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()
# Out:
# Using TensorFlow backend.

# %%
#optimus 5-prime functions 
def test_data(df, model, test_seq, obs_col, output_col='pred'):
    '''Predict mean ribosome load using model and test set UTRs'''
    
    # Scale the test set mean ribosome load
    scaler = preprocessing.StandardScaler()
    scaler.fit(df[obs_col].reshape(-1,1))
    
    # Make predictions
    predictions = model.predict(test_seq).reshape(-1)
    
    # Inverse scaled predicted mean ribosome load and return in a column labeled 'pred'
    df.loc[:,output_col] = scaler.inverse_transform(predictions)
    return df


def one_hot_encode(df, col='utr', seq_len=50):
    # Dictionary returning one-hot encoding of nucleotides. 
    nuc_d = {'a':[1,0,0,0],'c':[0,1,0,0],'g':[0,0,1,0],'t':[0,0,0,1], 'n':[0,0,0,0]}
    
    # Creat empty matrix.
    vectors=np.empty([len(df),seq_len,4])
    
    # Iterate through UTRs and one-hot encode
    for i,seq in enumerate(df[col].str[:seq_len]): 
        seq = seq.lower()
        a = np.array([nuc_d[x] for x in seq])
        vectors[i] = a
    return vectors


def r2(x,y):
    slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
    return r_value**2


#Train data
df = pd.read_csv("../../../seqprop/examples/optimus5/GSM3130435_egfp_unmod_1.csv")

df.sort_values('total_reads', inplace=True, ascending=False)
df.reset_index(inplace=True, drop=True)
df = df.iloc[:280000]
# The training set has 260k UTRs and the test set has 20k UTRs.
#e_test = df.iloc[:20000].copy().reset_index(drop = True)
e_train = df.iloc[20000:].copy().reset_index(drop = True)
e_train.loc[:,'scaled_rl'] = preprocessing.StandardScaler().fit_transform(e_train.loc[:,'rl'].values.reshape(-1,1))

seq_e_train = one_hot_encode(e_train,seq_len=50)
x_train = seq_e_train
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1], x_train.shape[2]))
y_train = np.array(e_train['scaled_rl'].values)
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("x_train.shape = " + str(x_train.shape))
print("y_train.shape = " + str(y_train.shape))
# Out:
# x_train.shape = (260000, 1, 50, 4)
# y_train.shape = (260000, 1)

# %%
#Load Predictor
predictor_path = 'optimusRetrainedMain.hdf5'

predictor = load_model(predictor_path)

predictor.trainable = False
predictor.compile(optimizer=keras.optimizers.SGD(lr=0.1), loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
#Generate (original) predictions

pred_train = predictor.predict(x_train[:, 0, ...], batch_size=32)

y_train = (y_train >= 0.)
y_train = np.concatenate([1. - y_train, y_train], axis=1)

pred_train = (pred_train >= 0.)
pred_train = np.concatenate([1. - pred_train, pred_train], axis=1)

# %%
from keras.layers import Input, Dense, Multiply, Flatten, Reshape, Conv2D, MaxPooling2D, GlobalMaxPooling2D, Activation
from keras.layers import BatchNormalization
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras import regularizers
from keras import backend as K

import tensorflow as tf
import numpy as np

from keras.layers import Layer, InputSpec
from keras import initializers, regularizers, constraints

class InstanceNormalization(Layer):
    def __init__(self, axes=(1, 2), trainable=True, **kwargs):
        super(InstanceNormalization, self).__init__(**kwargs)
        self.axes = axes
        self.trainable = trainable
    def build(self, input_shape):
        self.beta  = self.add_weight(name='beta',shape=(input_shape[-1],),
                                     initializer='zeros',trainable=self.trainable)
        self.gamma = self.add_weight(name='gamma',shape=(input_shape[-1],),
                                     initializer='ones',trainable=self.trainable)
    def call(self, inputs):
        mean, variance = tf.nn.moments(inputs, self.axes, keep_dims=True)
        return tf.nn.batch_normalization(inputs, mean, variance, self.beta, self.gamma, 1e-6)

def bernoulli_sampling (prob):
    """ Sampling Bernoulli distribution by given probability.

    Args:
    - prob: P(Y = 1) in Bernoulli distribution.

    Returns:
    - samples: samples from Bernoulli distribution
    """  

    n, x_len, y_len, d = prob.shape
    samples = np.random.binomial(1, prob, (n, x_len, y_len, d))

    return samples

class INVASE():
    """INVASE class.

    Attributes:
    - x_train: training features
    - y_train: training labels
    - model_type: invase or invase_minus
    - model_parameters:
      - actor_h_dim: hidden state dimensions for actor
      - critic_h_dim: hidden state dimensions for critic
      - n_layer: the number of layers
      - batch_size: the number of samples in mini batch
      - iteration: the number of iterations
      - activation: activation function of models
      - learning_rate: learning rate of model training
      - lamda: hyper-parameter of INVASE
    """

    def __init__(self, x_train, y_train, model_type, model_parameters):

        self.lamda = model_parameters['lamda']
        self.actor_h_dim = model_parameters['actor_h_dim']
        self.critic_h_dim = model_parameters['critic_h_dim']
        self.n_layer = model_parameters['n_layer']
        self.batch_size = model_parameters['batch_size']
        self.iteration = model_parameters['iteration']
        self.activation = model_parameters['activation']
        self.learning_rate = model_parameters['learning_rate']

        #Modified Code
        self.x_len = x_train.shape[1]
        self.y_len = x_train.shape[2]
        self.dim = x_train.shape[3] 
        self.label_dim = y_train.shape[1]

        self.model_type = model_type

        optimizer = Adam(self.learning_rate)

        # Build and compile critic
        self.critic = self.build_critic()
        self.critic.compile(loss='categorical_crossentropy', 
                            optimizer=optimizer, metrics=['acc'])

        # Build and compile the actor
        self.actor = self.build_actor()
        self.actor.compile(loss=self.actor_loss, optimizer=optimizer)

        if self.model_type == 'invase':
            # Build and compile the baseline
            self.baseline = self.build_baseline()
            self.baseline.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])


    def actor_loss(self, y_true, y_pred):
        """Custom loss for the actor.

        Args:
          - y_true:
            - actor_out: actor output after sampling
            - critic_out: critic output 
            - baseline_out: baseline output (only for invase)
          - y_pred: output of the actor network

        Returns:
          - loss: actor loss
        """
        
        y_pred = K.reshape(y_pred, (K.shape(y_pred)[0], self.x_len*self.y_len*1))
        y_true = y_true[:, 0, 0, :]

        # Actor output
        actor_out = y_true[:, :self.x_len*self.y_len*1]
        # Critic output
        critic_out = y_true[:, self.x_len*self.y_len*1:(self.x_len*self.y_len*1+self.label_dim)]

        if self.model_type == 'invase':
            # Baseline output
            baseline_out = \
            y_true[:, (self.x_len*self.y_len*1+self.label_dim):(self.x_len*self.y_len*1+2*self.label_dim)]
            # Ground truth label
            y_out = y_true[:, (self.x_len*self.y_len*1+2*self.label_dim):]        
        elif self.model_type == 'invase_minus':
            # Ground truth label
            y_out = y_true[:, (self.x_len*self.y_len*1+self.label_dim):]         

        # Critic loss
        critic_loss = -tf.reduce_sum(y_out * tf.log(critic_out + 1e-8), axis = 1)  

        if self.model_type == 'invase':        
            # Baseline loss
            baseline_loss = -tf.reduce_sum(y_out * tf.log(baseline_out + 1e-8), 
                                         axis = 1)  
            # Reward
            Reward = -(critic_loss - baseline_loss)
        elif self.model_type == 'invase_minus':
            Reward = -critic_loss

        # Policy gradient loss computation. 
        custom_actor_loss = \
        Reward * tf.reduce_sum(actor_out * K.log(y_pred + 1e-8) + \
        (1-actor_out) * K.log(1-y_pred + 1e-8), axis = 1) - \
        self.lamda * tf.reduce_mean(y_pred, axis = 1)

        # custom actor loss
        custom_actor_loss = tf.reduce_mean(-custom_actor_loss)

        return custom_actor_loss


    def build_actor(self):
        """Build actor.

        Use feature as the input and output selection probability
        """
        actor_model = Sequential()
        
        actor_model.add(Conv2D(self.actor_h_dim, (1, 7), padding='same', activation='linear'))
        actor_model.add(InstanceNormalization())
        actor_model.add(Activation(self.activation))
        for _ in range(self.n_layer - 2):
            actor_model.add(Conv2D(self.actor_h_dim, (1, 7), padding='same', activation='linear'))
            actor_model.add(InstanceNormalization())
            actor_model.add(Activation(self.activation))
        actor_model.add(Conv2D(1, (1, 1), padding='same', activation='sigmoid'))

        feature = Input(shape=(self.x_len, self.y_len, self.dim), dtype='float32')
        selection_probability = actor_model(feature)

        return Model(feature, selection_probability)


    def build_critic(self):
        """Build critic.

        Use selected feature as the input and predict labels
        """
        critic_model = Sequential()
        
        critic_model.add(Conv2D(self.critic_h_dim, (1, 7), padding='same', activation='linear'))
        critic_model.add(InstanceNormalization())
        critic_model.add(Activation(self.activation))
        for _ in range(self.n_layer - 2):
            critic_model.add(Conv2D(self.critic_h_dim, (1, 7), padding='same', activation='linear'))
            critic_model.add(InstanceNormalization())
            critic_model.add(Activation(self.activation))
        critic_model.add(Flatten())
        critic_model.add(Dense(self.critic_h_dim, activation=self.activation))
        critic_model.add(Dropout(0.2))
        critic_model.add(Dense(self.label_dim, activation ='softmax'))

        ## Inputs
        # Features
        feature = Input(shape=(self.x_len, self.y_len, self.dim), dtype='float32')
        # Binary selection
        selection = Input(shape=(self.x_len, self.y_len, 1), dtype='float32')         

        # Element-wise multiplication
        critic_model_input = Multiply()([feature, selection])
        y_hat = critic_model(critic_model_input)

        return Model([feature, selection], y_hat)


    def build_baseline(self):
        """Build baseline.

        Use the feature as the input and predict labels
        """
        baseline_model = Sequential()
        
        baseline_model.add(Conv2D(self.critic_h_dim, (1, 7), padding='same', activation='linear'))
        baseline_model.add(InstanceNormalization())
        baseline_model.add(Activation(self.activation))
        for _ in range(self.n_layer - 2):
            baseline_model.add(Conv2D(self.critic_h_dim, (1, 7), padding='same', activation='linear'))
            baseline_model.add(InstanceNormalization())
            baseline_model.add(Activation(self.activation))
        baseline_model.add(Flatten())
        baseline_model.add(Dense(self.critic_h_dim, activation=self.activation))
        baseline_model.add(Dropout(0.2))
        baseline_model.add(Dense(self.label_dim, activation ='softmax'))

        # Input
        feature = Input(shape=(self.x_len, self.y_len, self.dim), dtype='float32')       
        # Output        
        y_hat = baseline_model(feature)

        return Model(feature, y_hat)


    def train(self, x_train, y_train):
        """Train INVASE.

        Args:
          - x_train: training features
          - y_train: training labels
        """

        for iter_idx in range(self.iteration):

            ## Train critic
            # Select a random batch of samples
            idx = np.random.randint(0, x_train.shape[0], self.batch_size)
            x_batch = x_train[idx,:]
            y_batch = y_train[idx,:]

            # Generate a batch of selection probability
            selection_probability = self.actor.predict(x_batch)            
            # Sampling the features based on the selection_probability
            selection = bernoulli_sampling(selection_probability)     
            # Critic loss
            critic_loss = self.critic.train_on_batch([x_batch, selection], y_batch)                        
            # Critic output
            critic_out = self.critic.predict([x_batch, selection])

            # Baseline output
            if self.model_type == 'invase':   
              # Baseline loss
              baseline_loss = self.baseline.train_on_batch(x_batch, y_batch)                        
              # Baseline output
              baseline_out = self.baseline.predict(x_batch)

            ## Train actor
            # Use multiple things as the y_true: 
            # - selection, critic_out, baseline_out, and ground truth (y_batch)
            if self.model_type == 'invase':
                y_batch_final = np.concatenate((np.reshape(selection, (y_batch.shape[0], -1)), 
                                            np.asarray(critic_out), 
                                            np.asarray(baseline_out), 
                                            y_batch), axis = 1)
            elif self.model_type == 'invase_minus':
                y_batch_final = np.concatenate((np.reshape(selection, (y_batch.shape[0], -1)), 
                                            np.asarray(critic_out), 
                                            y_batch), axis = 1)

            y_batch_final = y_batch_final[:, None, None, :]
            
            # Train the actor
            actor_loss = self.actor.train_on_batch(x_batch, y_batch_final)

            if self.model_type == 'invase':
                # Print the progress
                dialog = 'Iterations: ' + str(iter_idx) + \
                     ', critic accuracy: ' + str(critic_loss[1]) + \
                     ', baseline accuracy: ' + str(baseline_loss[1]) + \
                     ', actor loss: ' + str(np.round(actor_loss,4))
            elif self.model_type == 'invase_minus':
                # Print the progress
                dialog = 'Iterations: ' + str(iter_idx) + \
                     ', critic accuracy: ' + str(critic_loss[1]) + \
                     ', actor loss: ' + str(np.round(actor_loss,4))

            if iter_idx % 100 == 0:
                print(dialog)

    def importance_score(self, x):
        """Return featuer importance score.

        Args:
          - x: feature

        Returns:
          - feature_importance: instance-wise feature importance for x
        """        
        feature_importance = self.actor.predict(x)        
        return np.asarray(feature_importance)


    def predict(self, x):
        """Predict outcomes.

        Args:
          - x: feature

        Returns:
          - y_hat: predictions    
        """        
        # Generate a batch of selection probability
        selection_probability = self.actor.predict(x)            
        # Sampling the features based on the selection_probability
        selection = bernoulli_sampling(selection_probability)   
        # Prediction 
        y_hat = self.critic.predict([x, selection])

        return np.asarray(y_hat)

# %%
#Gradient saliency/backprop visualization

import matplotlib.collections as collections
import operator
import matplotlib.pyplot as plt

import matplotlib.cm as cm
import matplotlib.colors as colors

import matplotlib as mpl
from matplotlib.text import TextPath
from matplotlib.patches import PathPatch, Rectangle
from matplotlib.font_manager import FontProperties
from matplotlib import gridspec
from matplotlib.ticker import FormatStrFormatter

def plot_importance_scores(importance_scores, ref_seq, figsize=(12, 2), score_clip=None, sequence_template='', plot_start=0, plot_end=96) :

    end_pos = ref_seq.find("#")
    
    fig = plt.figure(figsize=figsize)
    
    ax = plt.gca()
    
    if score_clip is not None :
        importance_scores = np.clip(np.copy(importance_scores), -score_clip, score_clip)
    
    max_score = np.max(np.sum(importance_scores[:, :], axis=0)) + 0.01

    for i in range(0, len(ref_seq)) :
        mutability_score = np.sum(importance_scores[:, i])
        dna_letter_at(ref_seq[i], i + 0.5, 0, mutability_score, ax)

    plt.sca(ax)
    plt.xlim((0, len(ref_seq)))
    plt.ylim((0, max_score))
    plt.axis('off')
    plt.yticks([0.0, max_score], [0.0, max_score], fontsize=16)
    
    for axis in fig.axes :
        axis.get_xaxis().set_visible(False)
        axis.get_yaxis().set_visible(False)
    
    plt.tight_layout()
    
    plt.show()

# %%
#Execute INVASE benchmark on synthetic datasets

mask_penalty = 0.5#0.1
hidden_dims = 32
n_layers = 4
epochs = 25
batch_size = 128

model_parameters = {
    'lamda': mask_penalty,
    'actor_h_dim': hidden_dims, 
    'critic_h_dim': hidden_dims,
    'n_layer': n_layers,
    'batch_size': batch_size,
    'iteration': int(x_train.shape[0] * epochs / batch_size), 
    'activation': 'relu', 
    'learning_rate': 0.0001
}

encoder = isol.OneHotEncoder(50)

score_clip = None

allFiles = ["optimus5_synthetic_random_insert_if_uorf_1_start_1_stop_variable_loc_512.csv",
            "optimus5_synthetic_random_insert_if_uorf_1_start_2_stop_variable_loc_512.csv",
            "optimus5_synthetic_random_insert_if_uorf_2_start_1_stop_variable_loc_512.csv",
            "optimus5_synthetic_random_insert_if_uorf_2_start_2_stop_variable_loc_512.csv",
            "optimus5_synthetic_examples_3.csv"]

#Train INVASE
invase_model = INVASE(x_train, pred_train, 'invase', model_parameters)

invase_model.train(x_train, pred_train)  

for csv_to_open in allFiles :
    
    #Load dataset for benchmarking 
    dataset_name = csv_to_open.replace(".csv", "")
    benchmarkSet = pd.read_csv(csv_to_open)
    
    seq_e_test = one_hot_encode(benchmarkSet, seq_len=50)
    x_test = seq_e_test[:, None, ...]
    
    print(x_test.shape)
    
    pred_test = predictor.predict(x_test[:, 0, ...], batch_size=32)
    y_test = pred_test

    y_test = (y_test >= 0.)
    y_test = np.concatenate([1. - y_test, y_test], axis=1)

    pred_test = (pred_test >= 0.)
    pred_test = np.concatenate([1. - pred_test, pred_test], axis=1)  

    importance_scores_test = invase_model.importance_score(x_test)
    
    #Evaluate INVASE model on train and test data

    invase_pred_train = invase_model.predict(x_train)
    invase_pred_test = invase_model.predict(x_test)

    print("Training Accuracy = " + str(np.sum(np.argmax(invase_pred_train, axis=1) == np.argmax(pred_train, axis=1)) / float(pred_train.shape[0])))
    print("Test Accuracy     = " + str(np.sum(np.argmax(invase_pred_test, axis=1) == np.argmax(pred_test, axis=1)) / float(pred_test.shape[0])))

    for plot_i in range(0, 3) :

        print("Test sequence " + str(plot_i) + ":")

        plot_dna_logo(x_test[plot_i, 0, :, :], sequence_template='N'*50, plot_sequence_template=True, figsize=(12, 1), plot_start=0, plot_end=50)
        plot_importance_scores(np.maximum(importance_scores_test[plot_i, 0, :, :].T, 0.), encoder.decode(x_test[plot_i, 0, :, :]), figsize=(12, 1), score_clip=score_clip, sequence_template='N'*50, plot_start=0, plot_end=50)

    #Save predicted importance scores

    model_name = "invase_" + dataset_name + "_conv_full_data"

    np.save(model_name + "_importance_scores_test", importance_scores_test)
# Out:
# Iterations: 0, critic accuracy: 0.390625, baseline accuracy: 0.609375, actor loss: -11.6949
# Iterations: 100, critic accuracy: 0.6171875, baseline accuracy: 0.640625, actor loss: -1.1258
# Iterations: 200, critic accuracy: 0.6484375, baseline accuracy: 0.6640625, actor loss: -0.1016
# Iterations: 300, critic accuracy: 0.5546875, baseline accuracy: 0.59375, actor loss: -0.5168
# Iterations: 400, critic accuracy: 0.59375, baseline accuracy: 0.5703125, actor loss: -1.1017
# Iterations: 500, critic accuracy: 0.65625, baseline accuracy: 0.609375, actor loss: -0.796
# Iterations: 600, critic accuracy: 0.6015625, baseline accuracy: 0.6171875, actor loss: -1.1892
# Iterations: 700, critic accuracy: 0.6171875, baseline accuracy: 0.6015625, actor loss: -0.5415
# Iterations: 800, critic accuracy: 0.6484375, baseline accuracy: 0.6796875, actor loss: -0.5854
# Iterations: 900, critic accuracy: 0.609375, baseline accuracy: 0.578125, actor loss: -0.7383
# Iterations: 1000, critic accuracy: 0.671875, baseline accuracy: 0.78125, actor loss: -2.6702
# Iterations: 1100, critic accuracy: 0.6015625, baseline accuracy: 0.71875, actor loss: -1.918
# Iterations: 1200, critic accuracy: 0.5703125, baseline accuracy: 0.6875, actor loss: -2.127
# Iterations: 1300, critic accuracy: 0.609375, baseline accuracy: 0.6953125, actor loss: -2.5803
# Iterations: 1400, critic accuracy: 0.5546875, baseline accuracy: 0.703125, actor loss: -2.9973
# Iterations: 1500, critic accuracy: 0.65625, baseline accuracy: 0.8046875, actor loss: -5.6637
# Iterations: 1600, critic accuracy: 0.6171875, baseline accuracy: 0.765625, actor loss: -4.6882
# Iterations: 1700, critic accuracy: 0.6171875, baseline accuracy: 0.8828125, actor loss: -6.1885
# Iterations: 1800, critic accuracy: 0.625, baseline accuracy: 0.875, actor loss: -6.5106
# Iterations: 1900, critic accuracy: 0.640625, baseline accuracy: 0.875, actor loss: -7.0292
# Iterations: 2000, critic accuracy: 0.578125, baseline accuracy: 0.8515625, actor loss: -5.8939
# Iterations: 2100, critic accuracy: 0.5703125, baseline accuracy: 0.90625, actor loss: -7.6099
# Iterations: 2200, critic accuracy: 0.625, baseline accuracy: 0.8671875, actor loss: -6.8492
# Iterations: 2300, critic accuracy: 0.59375, baseline accuracy: 0.8984375, actor loss: -7.5056
# Iterations: 2400, critic accuracy: 0.6640625, baseline accuracy: 0.921875, actor loss: -7.237
# Iterations: 2500, critic accuracy: 0.625, baseline accuracy: 0.890625, actor loss: -5.3026
# Iterations: 2600, critic accuracy: 0.6484375, baseline accuracy: 0.890625, actor loss: -6.5486
# Iterations: 2700, critic accuracy: 0.546875, baseline accuracy: 0.8984375, actor loss: -6.223
# Iterations: 2800, critic accuracy: 0.578125, baseline accuracy: 0.859375, actor loss: -6.8185
# Iterations: 2900, critic accuracy: 0.5859375, baseline accuracy: 0.90625, actor loss: -6.8197
# Iterations: 3000, critic accuracy: 0.625, baseline accuracy: 0.921875, actor loss: -6.7912
# Iterations: 3100, critic accuracy: 0.6015625, baseline accuracy: 0.9375, actor loss: -6.8764
# Iterations: 3200, critic accuracy: 0.6015625, baseline accuracy: 0.8515625, actor loss: -5.4695
# Iterations: 3300, critic accuracy: 0.5703125, baseline accuracy: 0.9140625, actor loss: -6.5216
# Iterations: 3400, critic accuracy: 0.609375, baseline accuracy: 0.8984375, actor loss: -5.6773
# Iterations: 3500, critic accuracy: 0.6875, baseline accuracy: 0.9296875, actor loss: -5.1542
# Iterations: 3600, critic accuracy: 0.59375, baseline accuracy: 0.8828125, actor loss: -5.1956
# Iterations: 3700, critic accuracy: 0.625, baseline accuracy: 0.9296875, actor loss: -5.6007
# Iterations: 3800, critic accuracy: 0.65625, baseline accuracy: 0.8828125, actor loss: -4.5584
# Iterations: 3900, critic accuracy: 0.625, baseline accuracy: 0.921875, actor loss: -5.4642
# Iterations: 4000, critic accuracy: 0.625, baseline accuracy: 0.9453125, actor loss: -6.1186
# Iterations: 4100, critic accuracy: 0.5703125, baseline accuracy: 0.8984375, actor loss: -4.9557
# Iterations: 4200, critic accuracy: 0.5703125, baseline accuracy: 0.9375, actor loss: -5.6133
# Iterations: 4300, critic accuracy: 0.625, baseline accuracy: 0.9453125, actor loss: -5.0569
# Iterations: 4400, critic accuracy: 0.6484375, baseline accuracy: 0.90625, actor loss: -4.8592
# Iterations: 4500, critic accuracy: 0.6328125, baseline accuracy: 0.8984375, actor loss: -4.5599
# Iterations: 4600, critic accuracy: 0.5390625, baseline accuracy: 0.953125, actor loss: -5.5266
# Iterations: 4700, critic accuracy: 0.59375, baseline accuracy: 0.9140625, actor loss: -4.9825
# Iterations: 4800, critic accuracy: 0.578125, baseline accuracy: 0.9609375, actor loss: -5.0746
# Iterations: 4900, critic accuracy: 0.703125, baseline accuracy: 0.90625, actor loss: -4.6208
# Iterations: 5000, critic accuracy: 0.6328125, baseline accuracy: 0.90625, actor loss: -3.8968
# Iterations: 5100, critic accuracy: 0.59375, baseline accuracy: 0.9375, actor loss: -4.678
# Iterations: 5200, critic accuracy: 0.609375, baseline accuracy: 0.8828125, actor loss: -3.6911
# Iterations: 5300, critic accuracy: 0.546875, baseline accuracy: 0.9140625, actor loss: -4.1596
# Iterations: 5400, critic accuracy: 0.65625, baseline accuracy: 0.9296875, actor loss: -3.6451
# Iterations: 5500, critic accuracy: 0.5859375, baseline accuracy: 0.9453125, actor loss: -4.4246
# Iterations: 5600, critic accuracy: 0.6328125, baseline accuracy: 0.96875, actor loss: -4.284
# Iterations: 5700, critic accuracy: 0.625, baseline accuracy: 0.9296875, actor loss: -4.0006
# Iterations: 5800, critic accuracy: 0.5390625, baseline accuracy: 0.9375, actor loss: -4.5173
# Iterations: 5900, critic accuracy: 0.65625, baseline accuracy: 0.9296875, actor loss: -3.8275
# Iterations: 6000, critic accuracy: 0.6015625, baseline accuracy: 0.953125, actor loss: -4.0728
# Iterations: 6100, critic accuracy: 0.65625, baseline accuracy: 0.9609375, actor loss: -4.1116
# Iterations: 6200, critic accuracy: 0.6640625, baseline accuracy: 0.96875, actor loss: -3.5808
# Iterations: 6300, critic accuracy: 0.6015625, baseline accuracy: 0.9296875, actor loss: -3.7118
# Iterations: 6400, critic accuracy: 0.65625, baseline accuracy: 0.9375, actor loss: -3.3352
# Iterations: 6500, critic accuracy: 0.640625, baseline accuracy: 0.96875, actor loss: -4.1158
# Iterations: 6600, critic accuracy: 0.7109375, baseline accuracy: 0.9609375, actor loss: -3.5784
# Iterations: 6700, critic accuracy: 0.6328125, baseline accuracy: 0.9140625, actor loss: -3.5007
# Iterations: 6800, critic accuracy: 0.4921875, baseline accuracy: 0.9453125, actor loss: -4.053
# Iterations: 6900, critic accuracy: 0.6015625, baseline accuracy: 0.9453125, actor loss: -3.4824
# Iterations: 7000, critic accuracy: 0.6640625, baseline accuracy: 0.9140625, actor loss: -3.1074
# Iterations: 7100, critic accuracy: 0.546875, baseline accuracy: 0.953125, actor loss: -3.521
# Iterations: 7200, critic accuracy: 0.5859375, baseline accuracy: 0.9140625, actor loss: -2.9394
# Iterations: 7300, critic accuracy: 0.609375, baseline accuracy: 0.953125, actor loss: -3.8403
# Iterations: 7400, critic accuracy: 0.6328125, baseline accuracy: 0.9140625, actor loss: -2.6146
# Iterations: 7500, critic accuracy: 0.59375, baseline accuracy: 0.9375, actor loss: -3.491
# Iterations: 7600, critic accuracy: 0.6328125, baseline accuracy: 0.9375, actor loss: -2.9986
# Iterations: 7700, critic accuracy: 0.625, baseline accuracy: 0.9609375, actor loss: -3.3308
# Iterations: 7800, critic accuracy: 0.625, baseline accuracy: 0.9296875, actor loss: -3.4045
# Iterations: 7900, critic accuracy: 0.59375, baseline accuracy: 0.9375, actor loss: -3.2892
# Iterations: 8000, critic accuracy: 0.5859375, baseline accuracy: 0.9453125, actor loss: -2.9703
# Iterations: 8100, critic accuracy: 0.625, baseline accuracy: 0.90625, actor loss: -2.4756
# Iterations: 8200, critic accuracy: 0.578125, baseline accuracy: 0.9375, actor loss: -3.5445
# Iterations: 8300, critic accuracy: 0.6015625, baseline accuracy: 0.953125, actor loss: -3.3239
# Iterations: 8400, critic accuracy: 0.640625, baseline accuracy: 0.9375, actor loss: -3.0634
# Iterations: 8500, critic accuracy: 0.59375, baseline accuracy: 0.9609375, actor loss: -3.2403
# Iterations: 8600, critic accuracy: 0.6484375, baseline accuracy: 0.9765625, actor loss: -3.0564
# Iterations: 8700, critic accuracy: 0.625, baseline accuracy: 0.90625, actor loss: -2.5869
# Iterations: 8800, critic accuracy: 0.59375, baseline accuracy: 0.9375, actor loss: -2.8325
# Iterations: 8900, critic accuracy: 0.6015625, baseline accuracy: 0.9375, actor loss: -3.1515
# Iterations: 9000, critic accuracy: 0.5390625, baseline accuracy: 0.9375, actor loss: -2.6737
# Iterations: 9100, critic accuracy: 0.5703125, baseline accuracy: 0.9609375, actor loss: -2.8068
# Iterations: 9200, critic accuracy: 0.6484375, baseline accuracy: 0.8984375, actor loss: -2.6373
# Iterations: 9300, critic accuracy: 0.6171875, baseline accuracy: 0.9375, actor loss: -2.1573
# Iterations: 9400, critic accuracy: 0.6953125, baseline accuracy: 0.9453125, actor loss: -2.3382
# Iterations: 9500, critic accuracy: 0.625, baseline accuracy: 0.953125, actor loss: -2.4022
# Iterations: 9600, critic accuracy: 0.6171875, baseline accuracy: 0.9375, actor loss: -2.3475
# Iterations: 9700, critic accuracy: 0.6171875, baseline accuracy: 0.9609375, actor loss: -2.4533
# Iterations: 9800, critic accuracy: 0.5625, baseline accuracy: 0.953125, actor loss: -2.5331
# Iterations: 9900, critic accuracy: 0.59375, baseline accuracy: 0.9296875, actor loss: -2.5194
# Iterations: 10000, critic accuracy: 0.6015625, baseline accuracy: 0.8984375, actor loss: -2.2558
# Iterations: 10100, critic accuracy: 0.5703125, baseline accuracy: 0.9609375, actor loss: -1.951
# Iterations: 10200, critic accuracy: 0.625, baseline accuracy: 0.953125, actor loss: -2.5938
# Iterations: 10300, critic accuracy: 0.59375, baseline accuracy: 0.9375, actor loss: -2.1474
# Iterations: 10400, critic accuracy: 0.5625, baseline accuracy: 0.9609375, actor loss: -2.2915
# Iterations: 10500, critic accuracy: 0.6015625, baseline accuracy: 0.953125, actor loss: -2.6112
# Iterations: 10600, critic accuracy: 0.703125, baseline accuracy: 0.9140625, actor loss: -2.3394
# Iterations: 10700, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -2.5675
# Iterations: 10800, critic accuracy: 0.6328125, baseline accuracy: 0.9296875, actor loss: -1.82
# Iterations: 10900, critic accuracy: 0.609375, baseline accuracy: 0.9140625, actor loss: -1.9315
# Iterations: 11000, critic accuracy: 0.6328125, baseline accuracy: 0.953125, actor loss: -2.2537
# Iterations: 11100, critic accuracy: 0.6328125, baseline accuracy: 0.9375, actor loss: -1.8976
# Iterations: 11200, critic accuracy: 0.59375, baseline accuracy: 0.890625, actor loss: -1.6103
# Iterations: 11300, critic accuracy: 0.609375, baseline accuracy: 0.9921875, actor loss: -2.291
# Iterations: 11400, critic accuracy: 0.6171875, baseline accuracy: 0.9296875, actor loss: -1.5192
# Iterations: 11500, critic accuracy: 0.671875, baseline accuracy: 0.9921875, actor loss: -2.1528
# Iterations: 11600, critic accuracy: 0.5625, baseline accuracy: 0.9375, actor loss: -1.7719
# Iterations: 11700, critic accuracy: 0.640625, baseline accuracy: 0.9765625, actor loss: -1.972
# Iterations: 11800, critic accuracy: 0.6171875, baseline accuracy: 0.9609375, actor loss: -1.9006
# Iterations: 11900, critic accuracy: 0.5625, baseline accuracy: 0.9609375, actor loss: -1.7794
# Iterations: 12000, critic accuracy: 0.640625, baseline accuracy: 0.96875, actor loss: -1.3668
# Iterations: 12100, critic accuracy: 0.6484375, baseline accuracy: 0.921875, actor loss: -1.9057
# Iterations: 12200, critic accuracy: 0.6640625, baseline accuracy: 0.953125, actor loss: -1.8946
# Iterations: 12300, critic accuracy: 0.6328125, baseline accuracy: 0.9765625, actor loss: -1.5756
# Iterations: 12400, critic accuracy: 0.5703125, baseline accuracy: 0.9453125, actor loss: -1.5437
# Iterations: 12500, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -1.4859
# Iterations: 12600, critic accuracy: 0.5625, baseline accuracy: 0.9609375, actor loss: -2.2667
# Iterations: 12700, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -1.7981
# Iterations: 12800, critic accuracy: 0.5703125, baseline accuracy: 0.9765625, actor loss: -1.5494
# Iterations: 12900, critic accuracy: 0.65625, baseline accuracy: 0.9296875, actor loss: -1.4729
# Iterations: 13000, critic accuracy: 0.6171875, baseline accuracy: 0.953125, actor loss: -1.7482
# Iterations: 13100, critic accuracy: 0.6171875, baseline accuracy: 0.9296875, actor loss: -1.1862
# Iterations: 13200, critic accuracy: 0.6328125, baseline accuracy: 0.9609375, actor loss: -1.8691
# Iterations: 13300, critic accuracy: 0.5625, baseline accuracy: 0.9296875, actor loss: -1.5655
# Iterations: 13400, critic accuracy: 0.6171875, baseline accuracy: 0.953125, actor loss: -1.4419
# Iterations: 13500, critic accuracy: 0.6015625, baseline accuracy: 0.953125, actor loss: -2.0248
# Iterations: 13600, critic accuracy: 0.5078125, baseline accuracy: 0.9609375, actor loss: -1.6477
# Iterations: 13700, critic accuracy: 0.6015625, baseline accuracy: 0.984375, actor loss: -1.6577
# Iterations: 13800, critic accuracy: 0.6171875, baseline accuracy: 0.9609375, actor loss: -1.5907
# Iterations: 13900, critic accuracy: 0.578125, baseline accuracy: 0.9765625, actor loss: -1.6068
# Iterations: 14000, critic accuracy: 0.5859375, baseline accuracy: 0.9296875, actor loss: -1.6829
# Iterations: 14100, critic accuracy: 0.5703125, baseline accuracy: 0.9453125, actor loss: -1.5752
# Iterations: 14200, critic accuracy: 0.6640625, baseline accuracy: 0.984375, actor loss: -1.7967
# Iterations: 14300, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -1.3755
# Iterations: 14400, critic accuracy: 0.640625, baseline accuracy: 0.9609375, actor loss: -1.3963
# Iterations: 14500, critic accuracy: 0.5859375, baseline accuracy: 0.984375, actor loss: -1.7422
# Iterations: 14600, critic accuracy: 0.65625, baseline accuracy: 0.9453125, actor loss: -1.185
# Iterations: 14700, critic accuracy: 0.6484375, baseline accuracy: 0.96875, actor loss: -1.3821
# Iterations: 14800, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -1.5678
# Iterations: 14900, critic accuracy: 0.6640625, baseline accuracy: 0.9609375, actor loss: -1.3759
# Iterations: 15000, critic accuracy: 0.5703125, baseline accuracy: 0.96875, actor loss: -1.5665
# Iterations: 15100, critic accuracy: 0.6171875, baseline accuracy: 0.9453125, actor loss: -1.7409
# Iterations: 15200, critic accuracy: 0.6953125, baseline accuracy: 0.9375, actor loss: -1.26
# Iterations: 15300, critic accuracy: 0.6484375, baseline accuracy: 0.9765625, actor loss: -1.4291
# Iterations: 15400, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -1.5081
# Iterations: 15500, critic accuracy: 0.6328125, baseline accuracy: 0.9609375, actor loss: -1.5285
# Iterations: 15600, critic accuracy: 0.671875, baseline accuracy: 0.9453125, actor loss: -1.2573
# Iterations: 15700, critic accuracy: 0.578125, baseline accuracy: 0.9765625, actor loss: -1.2832
# Iterations: 15800, critic accuracy: 0.59375, baseline accuracy: 0.9609375, actor loss: -1.272
# Iterations: 15900, critic accuracy: 0.546875, baseline accuracy: 0.9453125, actor loss: -1.7328
# Iterations: 16000, critic accuracy: 0.65625, baseline accuracy: 0.96875, actor loss: -1.2042
# Iterations: 16100, critic accuracy: 0.625, baseline accuracy: 0.921875, actor loss: -1.5365
# Iterations: 16200, critic accuracy: 0.5234375, baseline accuracy: 0.9609375, actor loss: -1.4983
# Iterations: 16300, critic accuracy: 0.5703125, baseline accuracy: 0.90625, actor loss: -1.0245
# Iterations: 16400, critic accuracy: 0.6328125, baseline accuracy: 0.96875, actor loss: -1.1197
# Iterations: 16500, critic accuracy: 0.53125, baseline accuracy: 0.984375, actor loss: -1.4992
# Iterations: 16600, critic accuracy: 0.5859375, baseline accuracy: 0.9453125, actor loss: -1.1811
# Iterations: 16700, critic accuracy: 0.640625, baseline accuracy: 0.9453125, actor loss: -1.3536
# Iterations: 16800, critic accuracy: 0.6875, baseline accuracy: 0.921875, actor loss: -1.313
# Iterations: 16900, critic accuracy: 0.6640625, baseline accuracy: 0.953125, actor loss: -1.4899
# Iterations: 17000, critic accuracy: 0.59375, baseline accuracy: 0.953125, actor loss: -1.3021
# Iterations: 17100, critic accuracy: 0.6640625, baseline accuracy: 0.9453125, actor loss: -0.8558
# Iterations: 17200, critic accuracy: 0.5859375, baseline accuracy: 0.9609375, actor loss: -1.1061
# Iterations: 17300, critic accuracy: 0.5703125, baseline accuracy: 0.984375, actor loss: -1.2339
# Iterations: 17400, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -1.1678
# Iterations: 17500, critic accuracy: 0.6015625, baseline accuracy: 1.0, actor loss: -1.1813
# Iterations: 17600, critic accuracy: 0.6015625, baseline accuracy: 0.96875, actor loss: -1.5175
# Iterations: 17700, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -1.1619
# Iterations: 17800, critic accuracy: 0.5859375, baseline accuracy: 0.953125, actor loss: -1.3384
# Iterations: 17900, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -1.288
# Iterations: 18000, critic accuracy: 0.65625, baseline accuracy: 0.9765625, actor loss: -1.0172
# Iterations: 18100, critic accuracy: 0.578125, baseline accuracy: 0.9453125, actor loss: -1.1547
# Iterations: 18200, critic accuracy: 0.6640625, baseline accuracy: 0.9609375, actor loss: -1.012
# Iterations: 18300, critic accuracy: 0.640625, baseline accuracy: 0.9765625, actor loss: -1.0621
# Iterations: 18400, critic accuracy: 0.5703125, baseline accuracy: 0.9609375, actor loss: -1.1192
# Iterations: 18500, critic accuracy: 0.59375, baseline accuracy: 0.96875, actor loss: -0.9789
# Iterations: 18600, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -1.1681
# Iterations: 18700, critic accuracy: 0.671875, baseline accuracy: 0.96875, actor loss: -1.1984
# Iterations: 18800, critic accuracy: 0.5703125, baseline accuracy: 0.96875, actor loss: -1.1124
# Iterations: 18900, critic accuracy: 0.5546875, baseline accuracy: 0.953125, actor loss: -1.1619
# Iterations: 19000, critic accuracy: 0.5859375, baseline accuracy: 0.96875, actor loss: -1.1882
# Iterations: 19100, critic accuracy: 0.6171875, baseline accuracy: 0.9609375, actor loss: -0.9115
# Iterations: 19200, critic accuracy: 0.5, baseline accuracy: 0.9765625, actor loss: -0.9728
# Iterations: 19300, critic accuracy: 0.6484375, baseline accuracy: 0.9609375, actor loss: -1.1245
# Iterations: 19400, critic accuracy: 0.6171875, baseline accuracy: 0.96875, actor loss: -0.7997
# Iterations: 19500, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -1.0918
# Iterations: 19600, critic accuracy: 0.609375, baseline accuracy: 0.9609375, actor loss: -0.9503
# Iterations: 19700, critic accuracy: 0.59375, baseline accuracy: 0.984375, actor loss: -1.012
# Iterations: 19800, critic accuracy: 0.6015625, baseline accuracy: 0.9609375, actor loss: -0.8398
# Iterations: 19900, critic accuracy: 0.5390625, baseline accuracy: 0.9765625, actor loss: -1.0337
# Iterations: 20000, critic accuracy: 0.546875, baseline accuracy: 0.984375, actor loss: -1.2248
# Iterations: 20100, critic accuracy: 0.625, baseline accuracy: 0.9765625, actor loss: -1.0032
# Iterations: 20200, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.9238
# Iterations: 20300, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.725
# Iterations: 20400, critic accuracy: 0.5859375, baseline accuracy: 0.9609375, actor loss: -0.9259
# Iterations: 20500, critic accuracy: 0.6484375, baseline accuracy: 0.96875, actor loss: -0.9345
# Iterations: 20600, critic accuracy: 0.625, baseline accuracy: 0.9609375, actor loss: -0.7664
# Iterations: 20700, critic accuracy: 0.5859375, baseline accuracy: 0.953125, actor loss: -1.1368
# Iterations: 20800, critic accuracy: 0.578125, baseline accuracy: 0.953125, actor loss: -0.9746
# Iterations: 20900, critic accuracy: 0.6171875, baseline accuracy: 0.984375, actor loss: -0.8495
# Iterations: 21000, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.7912
# Iterations: 21100, critic accuracy: 0.5625, baseline accuracy: 0.9609375, actor loss: -0.7289
# Iterations: 21200, critic accuracy: 0.5859375, baseline accuracy: 0.9609375, actor loss: -0.9663
# Iterations: 21300, critic accuracy: 0.53125, baseline accuracy: 0.96875, actor loss: -0.7096
# Iterations: 21400, critic accuracy: 0.625, baseline accuracy: 0.9609375, actor loss: -0.6657
# Iterations: 21500, critic accuracy: 0.6640625, baseline accuracy: 0.96875, actor loss: -0.8072
# Iterations: 21600, critic accuracy: 0.625, baseline accuracy: 0.9375, actor loss: -0.8531
# Iterations: 21700, critic accuracy: 0.6171875, baseline accuracy: 0.96875, actor loss: -0.7932
# Iterations: 21800, critic accuracy: 0.6015625, baseline accuracy: 0.9609375, actor loss: -0.9844
# Iterations: 21900, critic accuracy: 0.5546875, baseline accuracy: 0.984375, actor loss: -1.0811
# Iterations: 22000, critic accuracy: 0.6640625, baseline accuracy: 0.9921875, actor loss: -0.7659
# Iterations: 22100, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.8605
# Iterations: 22200, critic accuracy: 0.5859375, baseline accuracy: 0.9609375, actor loss: -0.853
# Iterations: 22300, critic accuracy: 0.6796875, baseline accuracy: 0.9765625, actor loss: -1.0773
# Iterations: 22400, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -0.8293
# Iterations: 22500, critic accuracy: 0.59375, baseline accuracy: 0.953125, actor loss: -0.7112
# Iterations: 22600, critic accuracy: 0.6484375, baseline accuracy: 0.96875, actor loss: -0.7392
# Iterations: 22700, critic accuracy: 0.640625, baseline accuracy: 0.9765625, actor loss: -0.7243
# Iterations: 22800, critic accuracy: 0.6015625, baseline accuracy: 0.984375, actor loss: -0.63
# Iterations: 22900, critic accuracy: 0.6875, baseline accuracy: 0.9375, actor loss: -0.7105
# Iterations: 23000, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -0.7587
# Iterations: 23100, critic accuracy: 0.6640625, baseline accuracy: 0.9453125, actor loss: -0.4959
# Iterations: 23200, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -0.7629
# Iterations: 23300, critic accuracy: 0.4921875, baseline accuracy: 0.9765625, actor loss: -0.8922
# Iterations: 23400, critic accuracy: 0.6953125, baseline accuracy: 0.9921875, actor loss: -0.7503
# Iterations: 23500, critic accuracy: 0.6328125, baseline accuracy: 0.96875, actor loss: -0.6796
# Iterations: 23600, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.7642
# Iterations: 23700, critic accuracy: 0.5703125, baseline accuracy: 0.9921875, actor loss: -0.7694
# Iterations: 23800, critic accuracy: 0.59375, baseline accuracy: 0.96875, actor loss: -0.7281
# Iterations: 23900, critic accuracy: 0.6328125, baseline accuracy: 0.96875, actor loss: -0.6845
# Iterations: 24000, critic accuracy: 0.5546875, baseline accuracy: 0.9609375, actor loss: -0.8183
# Iterations: 24100, critic accuracy: 0.6796875, baseline accuracy: 0.9609375, actor loss: -0.6726
# Iterations: 24200, critic accuracy: 0.5625, baseline accuracy: 0.9609375, actor loss: -0.6525
# Iterations: 24300, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.3842
# Iterations: 24400, critic accuracy: 0.5546875, baseline accuracy: 0.9609375, actor loss: -0.5807
# Iterations: 24500, critic accuracy: 0.59375, baseline accuracy: 0.953125, actor loss: -0.5305
# Iterations: 24600, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.6988
# Iterations: 24700, critic accuracy: 0.65625, baseline accuracy: 0.9921875, actor loss: -0.6599
# Iterations: 24800, critic accuracy: 0.5234375, baseline accuracy: 0.9921875, actor loss: -0.8069
# Iterations: 24900, critic accuracy: 0.703125, baseline accuracy: 0.9765625, actor loss: -0.6373
# Iterations: 25000, critic accuracy: 0.671875, baseline accuracy: 0.96875, actor loss: -0.5438
# Iterations: 25100, critic accuracy: 0.578125, baseline accuracy: 0.9765625, actor loss: -0.7008
# Iterations: 25200, critic accuracy: 0.5625, baseline accuracy: 0.9375, actor loss: -0.4803
# Iterations: 25300, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.594
# Iterations: 25400, critic accuracy: 0.578125, baseline accuracy: 0.9765625, actor loss: -0.4706
# Iterations: 25500, critic accuracy: 0.546875, baseline accuracy: 0.9609375, actor loss: -0.5119
# Iterations: 25600, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.7591
# Iterations: 25700, critic accuracy: 0.6171875, baseline accuracy: 0.9453125, actor loss: -0.5087
# Iterations: 25800, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -0.4001
# Iterations: 25900, critic accuracy: 0.609375, baseline accuracy: 0.9609375, actor loss: -0.5645
# Iterations: 26000, critic accuracy: 0.5703125, baseline accuracy: 0.9765625, actor loss: -0.3184
# Iterations: 26100, critic accuracy: 0.6328125, baseline accuracy: 0.96875, actor loss: -0.405
# Iterations: 26200, critic accuracy: 0.5625, baseline accuracy: 0.953125, actor loss: -0.6042
# Iterations: 26300, critic accuracy: 0.625, baseline accuracy: 0.9765625, actor loss: -0.4578
# Iterations: 26400, critic accuracy: 0.609375, baseline accuracy: 0.96875, actor loss: -0.2949
# Iterations: 26500, critic accuracy: 0.640625, baseline accuracy: 0.953125, actor loss: -0.5873
# Iterations: 26600, critic accuracy: 0.5703125, baseline accuracy: 0.9921875, actor loss: -0.9273
# Iterations: 26700, critic accuracy: 0.5390625, baseline accuracy: 0.984375, actor loss: -0.7817
# Iterations: 26800, critic accuracy: 0.6171875, baseline accuracy: 0.96875, actor loss: -0.3524
# Iterations: 26900, critic accuracy: 0.6484375, baseline accuracy: 1.0, actor loss: -0.488
# Iterations: 27000, critic accuracy: 0.59375, baseline accuracy: 1.0, actor loss: -0.4237
# Iterations: 27100, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.3134
# Iterations: 27200, critic accuracy: 0.5546875, baseline accuracy: 0.9765625, actor loss: -0.5322
# Iterations: 27300, critic accuracy: 0.6640625, baseline accuracy: 0.9921875, actor loss: -0.5451
# Iterations: 27400, critic accuracy: 0.5859375, baseline accuracy: 0.9921875, actor loss: -0.5428
# Iterations: 27500, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -0.5594
# Iterations: 27600, critic accuracy: 0.546875, baseline accuracy: 0.984375, actor loss: -0.7172
# Iterations: 27700, critic accuracy: 0.640625, baseline accuracy: 0.96875, actor loss: -0.4961
# Iterations: 27800, critic accuracy: 0.65625, baseline accuracy: 0.9609375, actor loss: -0.5446
# Iterations: 27900, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -0.7016
# Iterations: 28000, critic accuracy: 0.5703125, baseline accuracy: 0.984375, actor loss: -0.6879
# Iterations: 28100, critic accuracy: 0.6796875, baseline accuracy: 0.96875, actor loss: -0.4604
# Iterations: 28200, critic accuracy: 0.6328125, baseline accuracy: 0.9765625, actor loss: -0.5301
# Iterations: 28300, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.9864
# Iterations: 28400, critic accuracy: 0.609375, baseline accuracy: 1.0, actor loss: -0.4714
# Iterations: 28500, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.553
# Iterations: 28600, critic accuracy: 0.6484375, baseline accuracy: 0.9609375, actor loss: -0.6144
# Iterations: 28700, critic accuracy: 0.6328125, baseline accuracy: 0.9765625, actor loss: -0.6085
# Iterations: 28800, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -0.4906
# Iterations: 28900, critic accuracy: 0.6484375, baseline accuracy: 0.9609375, actor loss: -0.2917
# Iterations: 29000, critic accuracy: 0.578125, baseline accuracy: 0.9609375, actor loss: -0.4561
# Iterations: 29100, critic accuracy: 0.5625, baseline accuracy: 0.96875, actor loss: -0.4155
# Iterations: 29200, critic accuracy: 0.6640625, baseline accuracy: 0.984375, actor loss: -0.4843
# Iterations: 29300, critic accuracy: 0.546875, baseline accuracy: 0.984375, actor loss: -0.715
# Iterations: 29400, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -0.3178
# Iterations: 29500, critic accuracy: 0.6796875, baseline accuracy: 0.9765625, actor loss: -0.3476
# Iterations: 29600, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.2711
# Iterations: 29700, critic accuracy: 0.53125, baseline accuracy: 0.9921875, actor loss: -0.3509
# Iterations: 29800, critic accuracy: 0.6484375, baseline accuracy: 1.0, actor loss: -0.4646
# Iterations: 29900, critic accuracy: 0.5234375, baseline accuracy: 0.96875, actor loss: -0.4297
# Iterations: 30000, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.4156
# Iterations: 30100, critic accuracy: 0.609375, baseline accuracy: 0.984375, actor loss: -0.5026
# Iterations: 30200, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.4872
# Iterations: 30300, critic accuracy: 0.671875, baseline accuracy: 0.984375, actor loss: -0.3384
# Iterations: 30400, critic accuracy: 0.5546875, baseline accuracy: 0.96875, actor loss: -0.4119
# Iterations: 30500, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.558
# Iterations: 30600, critic accuracy: 0.609375, baseline accuracy: 0.9921875, actor loss: -0.5255
# Iterations: 30700, critic accuracy: 0.546875, baseline accuracy: 0.9921875, actor loss: -0.4363
# Iterations: 30800, critic accuracy: 0.6484375, baseline accuracy: 0.9765625, actor loss: -0.438
# Iterations: 30900, critic accuracy: 0.5859375, baseline accuracy: 0.9921875, actor loss: -0.5692
# Iterations: 31000, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.3191
# Iterations: 31100, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.5749
# Iterations: 31200, critic accuracy: 0.609375, baseline accuracy: 0.9453125, actor loss: -0.2869
# Iterations: 31300, critic accuracy: 0.5390625, baseline accuracy: 0.9765625, actor loss: -0.4412
# Iterations: 31400, critic accuracy: 0.578125, baseline accuracy: 0.9921875, actor loss: -0.3022
# Iterations: 31500, critic accuracy: 0.5703125, baseline accuracy: 0.9375, actor loss: -0.2388
# Iterations: 31600, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -0.3143
# Iterations: 31700, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -0.5381
# Iterations: 31800, critic accuracy: 0.625, baseline accuracy: 0.9453125, actor loss: -0.3937
# Iterations: 31900, critic accuracy: 0.640625, baseline accuracy: 0.9765625, actor loss: -0.4334
# Iterations: 32000, critic accuracy: 0.53125, baseline accuracy: 0.96875, actor loss: -0.3323
# Iterations: 32100, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -0.4484
# Iterations: 32200, critic accuracy: 0.59375, baseline accuracy: 0.984375, actor loss: -0.3171
# Iterations: 32300, critic accuracy: 0.5703125, baseline accuracy: 0.96875, actor loss: -0.3204
# Iterations: 32400, critic accuracy: 0.53125, baseline accuracy: 0.9921875, actor loss: -0.4391
# Iterations: 32500, critic accuracy: 0.6015625, baseline accuracy: 0.9609375, actor loss: -0.3589
# Iterations: 32600, critic accuracy: 0.671875, baseline accuracy: 0.96875, actor loss: -0.331
# Iterations: 32700, critic accuracy: 0.59375, baseline accuracy: 0.984375, actor loss: -0.5328
# Iterations: 32800, critic accuracy: 0.5859375, baseline accuracy: 0.984375, actor loss: -0.3192
# Iterations: 32900, critic accuracy: 0.6484375, baseline accuracy: 0.984375, actor loss: -0.4482
# Iterations: 33000, critic accuracy: 0.53125, baseline accuracy: 0.96875, actor loss: -0.5094
# Iterations: 33100, critic accuracy: 0.6328125, baseline accuracy: 0.984375, actor loss: -0.3378
# Iterations: 33200, critic accuracy: 0.65625, baseline accuracy: 0.96875, actor loss: -0.4275
# Iterations: 33300, critic accuracy: 0.5625, baseline accuracy: 0.9765625, actor loss: -0.3597
# Iterations: 33400, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.2339
# Iterations: 33500, critic accuracy: 0.609375, baseline accuracy: 0.96875, actor loss: -0.502
# Iterations: 33600, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.3757
# Iterations: 33700, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -0.3982
# Iterations: 33800, critic accuracy: 0.65625, baseline accuracy: 0.96875, actor loss: -0.4543
# Iterations: 33900, critic accuracy: 0.6015625, baseline accuracy: 0.96875, actor loss: -0.3459
# Iterations: 34000, critic accuracy: 0.578125, baseline accuracy: 0.9765625, actor loss: -0.2894
# Iterations: 34100, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -0.3614
# Iterations: 34200, critic accuracy: 0.5546875, baseline accuracy: 0.96875, actor loss: -0.6307
# Iterations: 34300, critic accuracy: 0.6640625, baseline accuracy: 0.9609375, actor loss: -0.5179
# Iterations: 34400, critic accuracy: 0.6015625, baseline accuracy: 0.9765625, actor loss: -0.2478
# Iterations: 34500, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.4428
# Iterations: 34600, critic accuracy: 0.59375, baseline accuracy: 0.9921875, actor loss: -0.5669
# Iterations: 34700, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -0.5902
# Iterations: 34800, critic accuracy: 0.6015625, baseline accuracy: 1.0, actor loss: -0.5143
# Iterations: 34900, critic accuracy: 0.5703125, baseline accuracy: 0.984375, actor loss: -0.3594
# Iterations: 35000, critic accuracy: 0.5703125, baseline accuracy: 0.9609375, actor loss: -0.3631
# Iterations: 35100, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.3549
# Iterations: 35200, critic accuracy: 0.59375, baseline accuracy: 0.96875, actor loss: -0.4825
# Iterations: 35300, critic accuracy: 0.609375, baseline accuracy: 0.984375, actor loss: -0.59
# Iterations: 35400, critic accuracy: 0.578125, baseline accuracy: 0.984375, actor loss: -0.63
# Iterations: 35500, critic accuracy: 0.6328125, baseline accuracy: 1.0, actor loss: -0.4946
# Iterations: 35600, critic accuracy: 0.5546875, baseline accuracy: 0.96875, actor loss: -0.2577
# Iterations: 35700, critic accuracy: 0.6484375, baseline accuracy: 0.9609375, actor loss: -0.3827
# Iterations: 35800, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.4469
# Iterations: 35900, critic accuracy: 0.6640625, baseline accuracy: 0.9921875, actor loss: -0.4232
# Iterations: 36000, critic accuracy: 0.65625, baseline accuracy: 0.9765625, actor loss: -0.3988
# Iterations: 36100, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.413
# Iterations: 36200, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.4894
# Iterations: 36300, critic accuracy: 0.671875, baseline accuracy: 0.9921875, actor loss: -0.4684
# Iterations: 36400, critic accuracy: 0.609375, baseline accuracy: 0.9921875, actor loss: -0.3637
# Iterations: 36500, critic accuracy: 0.6328125, baseline accuracy: 0.9921875, actor loss: -0.4316
# Iterations: 36600, critic accuracy: 0.59375, baseline accuracy: 0.9921875, actor loss: -0.5319
# Iterations: 36700, critic accuracy: 0.6640625, baseline accuracy: 0.953125, actor loss: -0.5505
# Iterations: 36800, critic accuracy: 0.5625, baseline accuracy: 0.96875, actor loss: -0.4092
# Iterations: 36900, critic accuracy: 0.6875, baseline accuracy: 0.9921875, actor loss: -0.4544
# Iterations: 37000, critic accuracy: 0.640625, baseline accuracy: 0.9921875, actor loss: -0.4858
# Iterations: 37100, critic accuracy: 0.6171875, baseline accuracy: 0.984375, actor loss: -0.446
# Iterations: 37200, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.5194
# Iterations: 37300, critic accuracy: 0.5546875, baseline accuracy: 0.9921875, actor loss: -0.6221
# Iterations: 37400, critic accuracy: 0.59375, baseline accuracy: 0.984375, actor loss: -0.2987
# Iterations: 37500, critic accuracy: 0.578125, baseline accuracy: 0.9921875, actor loss: -0.4053
# Iterations: 37600, critic accuracy: 0.6171875, baseline accuracy: 0.984375, actor loss: -0.366
# Iterations: 37700, critic accuracy: 0.609375, baseline accuracy: 0.96875, actor loss: -0.2434
# Iterations: 37800, critic accuracy: 0.5859375, baseline accuracy: 0.96875, actor loss: -0.2363
# Iterations: 37900, critic accuracy: 0.6484375, baseline accuracy: 1.0, actor loss: -0.5437
# Iterations: 38000, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.4854
# Iterations: 38100, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.3009
# Iterations: 38200, critic accuracy: 0.6484375, baseline accuracy: 0.9453125, actor loss: -0.1635
# Iterations: 38300, critic accuracy: 0.6328125, baseline accuracy: 0.9921875, actor loss: -0.1969
# Iterations: 38400, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.3192
# Iterations: 38500, critic accuracy: 0.6796875, baseline accuracy: 0.9765625, actor loss: -0.4024
# Iterations: 38600, critic accuracy: 0.546875, baseline accuracy: 0.984375, actor loss: -0.3985
# Iterations: 38700, critic accuracy: 0.5546875, baseline accuracy: 0.9921875, actor loss: -0.1934
# Iterations: 38800, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.1922
# Iterations: 38900, critic accuracy: 0.5234375, baseline accuracy: 0.9921875, actor loss: -0.467
# Iterations: 39000, critic accuracy: 0.5390625, baseline accuracy: 0.9921875, actor loss: -0.2484
# Iterations: 39100, critic accuracy: 0.640625, baseline accuracy: 0.9609375, actor loss: -0.2999
# Iterations: 39200, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.2976
# Iterations: 39300, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: 0.0432
# Iterations: 39400, critic accuracy: 0.59375, baseline accuracy: 0.984375, actor loss: -0.3964
# Iterations: 39500, critic accuracy: 0.59375, baseline accuracy: 0.96875, actor loss: -0.161
# Iterations: 39600, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.2739
# Iterations: 39700, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.3929
# Iterations: 39800, critic accuracy: 0.5546875, baseline accuracy: 0.984375, actor loss: -0.3611
# Iterations: 39900, critic accuracy: 0.625, baseline accuracy: 1.0, actor loss: -0.2849
# Iterations: 40000, critic accuracy: 0.625, baseline accuracy: 0.9765625, actor loss: -0.2782
# Iterations: 40100, critic accuracy: 0.6328125, baseline accuracy: 0.9765625, actor loss: -0.2893
# Iterations: 40200, critic accuracy: 0.5625, baseline accuracy: 0.9921875, actor loss: -0.3086
# Iterations: 40300, critic accuracy: 0.578125, baseline accuracy: 0.984375, actor loss: -0.312
# Iterations: 40400, critic accuracy: 0.7109375, baseline accuracy: 0.9921875, actor loss: -0.2047
# Iterations: 40500, critic accuracy: 0.6328125, baseline accuracy: 0.984375, actor loss: -0.1942
# Iterations: 40600, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.1701
# Iterations: 40700, critic accuracy: 0.625, baseline accuracy: 0.9921875, actor loss: -0.2321
# Iterations: 40800, critic accuracy: 0.625, baseline accuracy: 0.953125, actor loss: -0.3899
# Iterations: 40900, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.3004
# Iterations: 41000, critic accuracy: 0.5703125, baseline accuracy: 0.984375, actor loss: -0.5099
# Iterations: 41100, critic accuracy: 0.578125, baseline accuracy: 0.984375, actor loss: -0.3925
# Iterations: 41200, critic accuracy: 0.5859375, baseline accuracy: 0.96875, actor loss: -0.2775
# Iterations: 41300, critic accuracy: 0.5703125, baseline accuracy: 0.96875, actor loss: -0.3439
# Iterations: 41400, critic accuracy: 0.5078125, baseline accuracy: 0.96875, actor loss: -0.2527
# Iterations: 41500, critic accuracy: 0.5703125, baseline accuracy: 0.9765625, actor loss: -0.2101
# Iterations: 41600, critic accuracy: 0.5859375, baseline accuracy: 0.96875, actor loss: -0.26
# Iterations: 41700, critic accuracy: 0.5390625, baseline accuracy: 0.9765625, actor loss: -0.1976
# Iterations: 41800, critic accuracy: 0.6953125, baseline accuracy: 0.9765625, actor loss: -0.172
# Iterations: 41900, critic accuracy: 0.625, baseline accuracy: 0.9921875, actor loss: -0.0889
# Iterations: 42000, critic accuracy: 0.65625, baseline accuracy: 1.0, actor loss: -0.144
# Iterations: 42100, critic accuracy: 0.609375, baseline accuracy: 0.96875, actor loss: -0.3076
# Iterations: 42200, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.4058
# Iterations: 42300, critic accuracy: 0.5390625, baseline accuracy: 0.9765625, actor loss: -0.2944
# Iterations: 42400, critic accuracy: 0.6328125, baseline accuracy: 0.9921875, actor loss: -0.2472
# Iterations: 42500, critic accuracy: 0.5390625, baseline accuracy: 1.0, actor loss: -0.1711
# Iterations: 42600, critic accuracy: 0.5390625, baseline accuracy: 0.9921875, actor loss: -0.1292
# Iterations: 42700, critic accuracy: 0.6015625, baseline accuracy: 0.984375, actor loss: -0.2548
# Iterations: 42800, critic accuracy: 0.59375, baseline accuracy: 0.9921875, actor loss: -0.2896
# Iterations: 42900, critic accuracy: 0.59375, baseline accuracy: 0.96875, actor loss: -0.2991
# Iterations: 43000, critic accuracy: 0.6328125, baseline accuracy: 0.984375, actor loss: -0.2766
# Iterations: 43100, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.403
# Iterations: 43200, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.2682
# Iterations: 43300, critic accuracy: 0.578125, baseline accuracy: 0.984375, actor loss: -0.461
# Iterations: 43400, critic accuracy: 0.5390625, baseline accuracy: 0.984375, actor loss: -0.4014
# Iterations: 43500, critic accuracy: 0.65625, baseline accuracy: 0.9921875, actor loss: -0.2681
# Iterations: 43600, critic accuracy: 0.6015625, baseline accuracy: 1.0, actor loss: -0.2106
# Iterations: 43700, critic accuracy: 0.546875, baseline accuracy: 0.9921875, actor loss: -0.2373
# Iterations: 43800, critic accuracy: 0.6171875, baseline accuracy: 0.9609375, actor loss: -0.2671
# Iterations: 43900, critic accuracy: 0.6328125, baseline accuracy: 0.984375, actor loss: -0.2733
# Iterations: 44000, critic accuracy: 0.671875, baseline accuracy: 0.9921875, actor loss: -0.2644
# Iterations: 44100, critic accuracy: 0.6328125, baseline accuracy: 0.9921875, actor loss: -0.2212
# Iterations: 44200, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.3337
# Iterations: 44300, critic accuracy: 0.609375, baseline accuracy: 0.9921875, actor loss: -0.4234
# Iterations: 44400, critic accuracy: 0.5859375, baseline accuracy: 0.984375, actor loss: -0.3705
# Iterations: 44500, critic accuracy: 0.5625, baseline accuracy: 0.96875, actor loss: -0.2749
# Iterations: 44600, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -0.2217
# Iterations: 44700, critic accuracy: 0.640625, baseline accuracy: 0.9921875, actor loss: -0.3239
# Iterations: 44800, critic accuracy: 0.578125, baseline accuracy: 0.984375, actor loss: -0.4722
# Iterations: 44900, critic accuracy: 0.609375, baseline accuracy: 0.96875, actor loss: -0.4476
# Iterations: 45000, critic accuracy: 0.515625, baseline accuracy: 0.9765625, actor loss: -0.3607
# Iterations: 45100, critic accuracy: 0.625, baseline accuracy: 0.9921875, actor loss: -0.2414
# Iterations: 45200, critic accuracy: 0.65625, baseline accuracy: 0.9921875, actor loss: -0.2751
# Iterations: 45300, critic accuracy: 0.609375, baseline accuracy: 0.9921875, actor loss: -0.1994
# Iterations: 45400, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.2233
# Iterations: 45500, critic accuracy: 0.578125, baseline accuracy: 0.96875, actor loss: -0.2655
# Iterations: 45600, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.2415
# Iterations: 45700, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -0.3277
# Iterations: 45800, critic accuracy: 0.5859375, baseline accuracy: 0.9765625, actor loss: -0.2907
# Iterations: 45900, critic accuracy: 0.46875, baseline accuracy: 0.984375, actor loss: -0.2122
# Iterations: 46000, critic accuracy: 0.625, baseline accuracy: 0.9765625, actor loss: -0.2191
# Iterations: 46100, critic accuracy: 0.6640625, baseline accuracy: 0.9765625, actor loss: -0.2766
# Iterations: 46200, critic accuracy: 0.640625, baseline accuracy: 0.9765625, actor loss: -0.2598
# Iterations: 46300, critic accuracy: 0.6171875, baseline accuracy: 0.9921875, actor loss: -0.2078
# Iterations: 46400, critic accuracy: 0.5859375, baseline accuracy: 0.96875, actor loss: -0.3805
# Iterations: 46500, critic accuracy: 0.625, baseline accuracy: 0.9921875, actor loss: -0.2561
# Iterations: 46600, critic accuracy: 0.6015625, baseline accuracy: 0.96875, actor loss: -0.2014
# Iterations: 46700, critic accuracy: 0.6484375, baseline accuracy: 0.9765625, actor loss: -0.3901
# Iterations: 46800, critic accuracy: 0.5625, baseline accuracy: 0.984375, actor loss: -0.3059
# Iterations: 46900, critic accuracy: 0.59375, baseline accuracy: 0.9921875, actor loss: -0.3874
# Iterations: 47000, critic accuracy: 0.6640625, baseline accuracy: 0.96875, actor loss: -0.232
# Iterations: 47100, critic accuracy: 0.5546875, baseline accuracy: 0.9609375, actor loss: -0.2928
# Iterations: 47200, critic accuracy: 0.6875, baseline accuracy: 0.984375, actor loss: -0.289
# Iterations: 47300, critic accuracy: 0.5703125, baseline accuracy: 0.9921875, actor loss: -0.2363
# Iterations: 47400, critic accuracy: 0.6171875, baseline accuracy: 0.984375, actor loss: -0.5919
# Iterations: 47500, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.3667
# Iterations: 47600, critic accuracy: 0.5625, baseline accuracy: 0.96875, actor loss: -0.3754
# Iterations: 47700, critic accuracy: 0.5390625, baseline accuracy: 0.96875, actor loss: -0.2525
# Iterations: 47800, critic accuracy: 0.671875, baseline accuracy: 0.9921875, actor loss: -0.3242
# Iterations: 47900, critic accuracy: 0.5859375, baseline accuracy: 0.984375, actor loss: -0.4084
# Iterations: 48000, critic accuracy: 0.6640625, baseline accuracy: 0.9765625, actor loss: -0.3819
# Iterations: 48100, critic accuracy: 0.546875, baseline accuracy: 0.96875, actor loss: -0.3308
# Iterations: 48200, critic accuracy: 0.640625, baseline accuracy: 0.9921875, actor loss: -0.3933
# Iterations: 48300, critic accuracy: 0.546875, baseline accuracy: 0.9609375, actor loss: -0.4078
# Iterations: 48400, critic accuracy: 0.5546875, baseline accuracy: 0.9921875, actor loss: -0.1819
# Iterations: 48500, critic accuracy: 0.6171875, baseline accuracy: 0.9765625, actor loss: -0.251
# Iterations: 48600, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -0.1353
# Iterations: 48700, critic accuracy: 0.6796875, baseline accuracy: 0.96875, actor loss: -0.3041
# Iterations: 48800, critic accuracy: 0.6015625, baseline accuracy: 1.0, actor loss: -0.272
# Iterations: 48900, critic accuracy: 0.6015625, baseline accuracy: 0.9921875, actor loss: -0.3257
# Iterations: 49000, critic accuracy: 0.609375, baseline accuracy: 0.9765625, actor loss: -0.1542
# Iterations: 49100, critic accuracy: 0.625, baseline accuracy: 0.9921875, actor loss: -0.1634
# Iterations: 49200, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.2562
# Iterations: 49300, critic accuracy: 0.625, baseline accuracy: 0.96875, actor loss: -0.2629
# Iterations: 49400, critic accuracy: 0.640625, baseline accuracy: 1.0, actor loss: -0.1888
# Iterations: 49500, critic accuracy: 0.6328125, baseline accuracy: 0.9921875, actor loss: -0.4525
# Iterations: 49600, critic accuracy: 0.5703125, baseline accuracy: 0.9609375, actor loss: -0.4094
# Iterations: 49700, critic accuracy: 0.6796875, baseline accuracy: 0.984375, actor loss: -0.1426
# Iterations: 49800, critic accuracy: 0.6171875, baseline accuracy: 0.984375, actor loss: -0.2763
# Iterations: 49900, critic accuracy: 0.5859375, baseline accuracy: 0.9921875, actor loss: -0.283
# Iterations: 50000, critic accuracy: 0.671875, baseline accuracy: 0.9921875, actor loss: -0.3273
# Iterations: 50100, critic accuracy: 0.59375, baseline accuracy: 0.9765625, actor loss: -0.2026
# Iterations: 50200, critic accuracy: 0.578125, baseline accuracy: 1.0, actor loss: -0.3214
# Iterations: 50300, critic accuracy: 0.5546875, baseline accuracy: 0.9765625, actor loss: -0.2305
# Iterations: 50400, critic accuracy: 0.640625, baseline accuracy: 0.984375, actor loss: -0.3434
# Iterations: 50500, critic accuracy: 0.625, baseline accuracy: 0.984375, actor loss: -0.2131
# Iterations: 50600, critic accuracy: 0.6875, baseline accuracy: 1.0, actor loss: -0.2584
# Iterations: 50700, critic accuracy: 0.578125, baseline accuracy: 0.9921875, actor loss: -0.5418
# (512, 1, 50, 4)
# Training Accuracy = 0.6066423076923076
# Test Accuracy     = 0.01953125
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# (512, 1, 50, 4)
# Training Accuracy = 0.6066423076923076
# Test Accuracy     = 0.052734375
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# (512, 1, 50, 4)
# Training Accuracy = 0.6066423076923076
# Test Accuracy     = 0.00390625
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# (512, 1, 50, 4)
# Training Accuracy = 0.6066423076923076
# Test Accuracy     = 0.001953125
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# (3, 1, 50, 4)
# Training Accuracy = 0.6066423076923076
# Test Accuracy     = 0.0
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
