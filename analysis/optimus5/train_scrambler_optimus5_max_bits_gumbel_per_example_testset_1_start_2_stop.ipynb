# %%
import keras
from keras.models import Sequential, Model, load_model

from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv1D, MaxPooling1D, LSTM, ConvLSTM2D, GRU, CuDNNLSTM, CuDNNGRU, BatchNormalization, LocallyConnected2D, Permute, TimeDistributed, Bidirectional
from keras.layers import Concatenate, Reshape, Softmax, Conv2DTranspose, Embedding, Multiply
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras import regularizers
from keras import backend as K
from keras.utils.generic_utils import Progbar
from keras.layers.merge import _Merge
import keras.losses

from functools import partial

from collections import defaultdict

import tensorflow as tf
from tensorflow.python.framework import ops

import isolearn.keras as iso

import numpy as np

import tensorflow as tf
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)
from sklearn import preprocessing
import pandas as pd

import os
import pickle
import numpy as np

import scipy.sparse as sp
import scipy.io as spio
import scipy as scp
import matplotlib.pyplot as plt

import isolearn.io as isoio
import isolearn.keras as isol

from sequence_logo_helper import plot_dna_logo, plot_importance_scores

import pandas as pd

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()

class EpochVariableCallback(Callback) :
    
    def __init__(self, my_variable, my_func) :
        self.my_variable = my_variable       
        self.my_func = my_func
        
    def on_epoch_begin(self, epoch, logs={}) :
        K.set_value(self.my_variable, self.my_func(K.get_value(self.my_variable), epoch))
# Out:
# Using TensorFlow backend.

# %%
#optimus 5-prime functions 
def test_data(df, model, test_seq, obs_col, output_col='pred'):
    '''Predict mean ribosome load using model and test set UTRs'''
    
    # Scale the test set mean ribosome load
    scaler = preprocessing.StandardScaler()
    scaler.fit(df[obs_col].reshape(-1,1))
    
    # Make predictions
    predictions = model.predict(test_seq).reshape(-1)
    
    # Inverse scaled predicted mean ribosome load and return in a column labeled 'pred'
    df.loc[:,output_col] = scaler.inverse_transform(predictions)
    return df


def one_hot_encode(df, col='utr', seq_len=50):
    # Dictionary returning one-hot encoding of nucleotides. 
    nuc_d = {'a':[1,0,0,0],'c':[0,1,0,0],'g':[0,0,1,0],'t':[0,0,0,1], 'n':[0,0,0,0]}
    
    # Creat empty matrix.
    vectors=np.empty([len(df),seq_len,4])
    
    # Iterate through UTRs and one-hot encode
    for i,seq in enumerate(df[col].str[:seq_len]): 
        seq = seq.lower()
        a = np.array([nuc_d[x] for x in seq])
        vectors[i] = a
    return vectors


def r2(x,y):
    slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
    return r_value**2


#Train data
e_train = pd.read_csv("bottom5KIFuAUGTop5KIFuAUG.csv")
e_train.loc[:,'scaled_rl'] = preprocessing.StandardScaler().fit_transform(e_train.loc[:,'rl'].values.reshape(-1,1))

seq_e_train = one_hot_encode(e_train,seq_len=50)
x_train = seq_e_train
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1], x_train.shape[2]))
y_train = np.array(e_train['scaled_rl'].values)
y_train = np.reshape(y_train, (y_train.shape[0],1))

#Test data
e_test = pd.read_csv("optimus5_synthetic_random_insert_if_uorf_1_start_2_stop_variable_loc_512.csv")

seq_e_test = one_hot_encode(e_test, seq_len=50)
x_test = seq_e_test
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1], x_test.shape[2]))
y_test = np.zeros(x_test.shape[0])
y_test = np.reshape(y_test, (y_test.shape[0],1))
drop_test = np.ones((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))

print("x_train.shape = " + str(x_train.shape))
print("x_test.shape = " + str(x_test.shape))

print("y_train.shape = " + str(y_train.shape))
print("y_test.shape = " + str(y_test.shape))
print("drop_test.shape = " + str(drop_test.shape))
# Out:
# x_train.shape = (15008, 1, 50, 4)
# x_test.shape = (512, 1, 50, 4)
# y_train.shape = (15008, 1)
# y_test.shape = (512, 1)
# drop_test.shape = (512, 1, 50, 1)

# %%
#Define sequence template

sequence_template = "N" * 50
sequence_mask = np.array([1 if sequence_template[j] == 'N' else 0 for j in range(len(sequence_template))])

# %%
#Visualize background sequence distribution

pseudo_count = 1.0

x_mean = (np.sum(x_train, axis=(0, 1)) + pseudo_count) / (x_train.shape[0] + 4. * pseudo_count)
x_mean_logits = np.log(x_mean / (1. - x_mean))

plot_dna_logo(np.copy(x_mean), sequence_template=sequence_template, figsize=(14, 0.65), logo_height=1.0, plot_start=0, plot_end=205)

# %%
#Calculate mean training set conservation

entropy = np.sum(x_mean * -np.log(x_mean), axis=-1) / np.log(2.0)
conservation = 2.0 - entropy

x_mean_conservation = np.sum(conservation) / np.sum(sequence_mask)

print("Mean conservation (bits) = " + str(x_mean_conservation))
# Out:
# Mean conservation (bits) = 0.032049298346210106

# %%
#Calculate mean training set kl-divergence against background

x_train_clipped = np.clip(np.copy(x_train[:, 0, :, :]), 1e-8, 1. - 1e-8)

kl_divs = np.sum(x_train_clipped * np.log(x_train_clipped / np.tile(np.expand_dims(x_mean, axis=0), (x_train_clipped.shape[0], 1, 1))), axis=-1) / np.log(2.0)

x_mean_kl_divs = np.sum(kl_divs * sequence_mask, axis=-1) / np.sum(sequence_mask)
x_mean_kl_div = np.mean(x_mean_kl_divs)

print("Mean KL Div against background (bits) = " + str(x_mean_kl_div))
# Out:
# Mean KL Div against background (bits) = 1.9679329305814974

# %%
from tensorflow.python.framework import ops

#Stochastic Binarized Neuron helper functions (Tensorflow)
#ST Estimator code adopted from https://r2rt.com/beyond-binary-ternary-and-one-hot-neurons.html
#See Github https://github.com/spitis/

def st_sampled_softmax(logits):
    with ops.name_scope("STSampledSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.squeeze(tf.multinomial(logits, 1), 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

def st_hardmax_softmax(logits):
    with ops.name_scope("STHardmaxSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.argmax(nt_probs, 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

@ops.RegisterGradient("STMul")
def st_mul(op, grad):
    return [grad, grad]

#Gumbel Distribution Sampler
def gumbel_softmax(logits, temperature=0.5) :
    gumbel_dist = tf.contrib.distributions.RelaxedOneHotCategorical(temperature, logits=logits)
    batch_dim = logits.get_shape().as_list()[0]
    onehot_dim = logits.get_shape().as_list()[1]
    return gumbel_dist.sample()

# %%
#aparent_l_test, aparent_d_test#PWM Masking and Sampling helper functions

def mask_pwm(inputs) :
    pwm, onehot_template, onehot_mask = inputs

    return pwm * onehot_mask + onehot_template

def sample_pwm_st(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = st_sampled_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def sample_pwm_gumbel(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = gumbel_softmax(flat_pwm, temperature=0.5)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

#Generator helper functions
def initialize_sequence_templates(generator, sequence_templates, background_matrices) :

    embedding_templates = []
    embedding_masks = []
    embedding_backgrounds = []

    for k in range(len(sequence_templates)) :
        sequence_template = sequence_templates[k]
        onehot_template = iso.OneHotEncoder(seq_length=len(sequence_template))(sequence_template).reshape((1, len(sequence_template), 4))

        for j in range(len(sequence_template)) :
            if sequence_template[j] not in ['N', 'X'] :
                nt_ix = np.argmax(onehot_template[0, j, :])
                onehot_template[:, j, :] = -4.0
                onehot_template[:, j, nt_ix] = 10.0
            elif sequence_template[j] == 'X' :
                onehot_template[:, j, :] = -1.0

        onehot_mask = np.zeros((1, len(sequence_template), 4))
        for j in range(len(sequence_template)) :
            if sequence_template[j] == 'N' :
                onehot_mask[:, j, :] = 1.0

        embedding_templates.append(onehot_template.reshape(1, -1))
        embedding_masks.append(onehot_mask.reshape(1, -1))
        embedding_backgrounds.append(background_matrices[k].reshape(1, -1))

    embedding_templates = np.concatenate(embedding_templates, axis=0)
    embedding_masks = np.concatenate(embedding_masks, axis=0)
    embedding_backgrounds = np.concatenate(embedding_backgrounds, axis=0)

    generator.get_layer('template_dense').set_weights([embedding_templates])
    generator.get_layer('template_dense').trainable = False

    generator.get_layer('mask_dense').set_weights([embedding_masks])
    generator.get_layer('mask_dense').trainable = False
    
    generator.get_layer('background_dense').set_weights([embedding_backgrounds])
    generator.get_layer('background_dense').trainable = False

#Generator construction function
def build_sampler(batch_size, seq_length, n_classes=1, n_samples=1, sample_mode='st') :

    #Initialize Reshape layer
    reshape_layer = Reshape((1, seq_length, 4))
    
    #Initialize background matrix
    onehot_background_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='zeros', name='background_dense')

    #Initialize template and mask matrices
    onehot_template_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='zeros', name='template_dense')
    onehot_mask_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='ones', name='mask_dense')

    #Initialize Templating and Masking Lambda layer
    masking_layer = Lambda(mask_pwm, output_shape = (1, seq_length, 4), name='masking_layer')
    background_layer = Lambda(lambda x: x[0] + x[1], name='background_layer')
    
    #Initialize PWM normalization layer
    pwm_layer = Softmax(axis=-1, name='pwm')
    
    #Initialize sampling layers
    sample_func = None
    if sample_mode == 'st' :
        sample_func = sample_pwm_st
    elif sample_mode == 'gumbel' :
        sample_func = sample_pwm_gumbel
    
    upsampling_layer = Lambda(lambda x: K.tile(x, [n_samples, 1, 1, 1]), name='upsampling_layer')
    sampling_layer = Lambda(sample_func, name='pwm_sampler')
    permute_layer = Lambda(lambda x: K.permute_dimensions(K.reshape(x, (n_samples, batch_size, 1, seq_length, 4)), (1, 0, 2, 3, 4)), name='permute_layer')
    
    def _sampler_func(class_input, raw_logits) :
        
        #Get Template and Mask
        onehot_background = reshape_layer(onehot_background_dense(class_input))
        onehot_template = reshape_layer(onehot_template_dense(class_input))
        onehot_mask = reshape_layer(onehot_mask_dense(class_input))
        
        #Add Template and Multiply Mask
        pwm_logits = masking_layer([background_layer([raw_logits, onehot_background]), onehot_template, onehot_mask])
        
        #Compute PWM (Nucleotide-wise Softmax)
        pwm = pwm_layer(pwm_logits)
        
        #Tile each PWM to sample from and create sample axis
        pwm_logits_upsampled = upsampling_layer(pwm_logits)
        sampled_pwm = sampling_layer(pwm_logits_upsampled)
        sampled_pwm = permute_layer(sampled_pwm)

        sampled_mask = permute_layer(upsampling_layer(onehot_mask))
        
        return pwm_logits, pwm, sampled_pwm, onehot_mask, sampled_mask
    
    return _sampler_func

# %%
#Scrambler network definition

from keras.layers import Layer, InputSpec
from keras import initializers, regularizers, constraints

class InstanceNormalization(Layer):
    def __init__(self, axes=(1, 2), trainable=True, **kwargs):
        super(InstanceNormalization, self).__init__(**kwargs)
        self.axes = axes
        self.trainable = trainable
    def build(self, input_shape):
        self.beta  = self.add_weight(name='beta',shape=(input_shape[-1],),
                                     initializer='zeros',trainable=self.trainable)
        self.gamma = self.add_weight(name='gamma',shape=(input_shape[-1],),
                                     initializer='ones',trainable=self.trainable)
    def call(self, inputs):
        mean, variance = tf.nn.moments(inputs, self.axes, keep_dims=True)
        return tf.nn.batch_normalization(inputs, mean, variance, self.beta, self.gamma, 1e-6)

def load_scrambler_network(seq_length, norm_mode='conv') :

    #Discriminator network definition
    
    seed_input = Lambda(lambda x: K.zeros((1, 1), dtype=tf.int32))
    
    mask_dense = Embedding(1, seq_length, embeddings_initializer='glorot_normal', name='scrambler_mask_dense')
    
    mask_reshape = Reshape((1, seq_length, 1))
    
    mask_conv, mask_norm = None, None
    if norm_mode is not None and norm_mode == 'conv' :
        mask_conv = Conv2D(1, (1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='scrambler_mask_conv')
    elif norm_mode is not None and norm_mode == 'norm' :
        mask_norm = InstanceNormalization(name='scrambler_mask_norm')
        #mask_norm = BatchNormalization(axis=-1, name='scrambler_mask_norm')
    
    mask_act = Activation('softplus')
    
    onehot_to_logits = Lambda(lambda x: 2. * x - 1., name='scrambler_onehot_to_logits')
    
    scale_logits = Lambda(lambda x: x[1] * K.tile(x[0], (1, 1, 1, 4)), name='scrambler_logit_scale')
    
    drop_multiply = Lambda(lambda x: x[0] * x[1], name='scrambler_drop_multiply')
    
    def _scrambler_func(sequence_input, drop_input) :

        mask_in = mask_reshape(mask_dense(seed_input(sequence_input)))
        
        #Final conv out
        if norm_mode is not None and norm_mode == 'conv' : 
            mask_out = mask_conv(mask_in)
        elif norm_mode is not None and norm_mode == 'norm' :
            mask_out = mask_norm(mask_in)
            #mask_out = mask_norm(mask_in, training=True)
        else :
            mask_out = mask_in
        
        mask_act_out = mask_act(mask_out)
        
        scores_out = drop_multiply([mask_act_out, drop_input])
        
        #Scale inputs by importance scores
        scaled_inputs = scale_logits([scores_out, onehot_to_logits(sequence_input)])
        
        return scaled_inputs, scores_out

    return _scrambler_func

# %%
#Keras loss functions

def get_margin_entropy_ame_masked(pwm_start, pwm_end, pwm_background, max_bits=1.0) :
    
    def _margin_entropy_ame_masked(pwm, pwm_mask) :
        conservation = pwm[:, 0, pwm_start:pwm_end, :] * K.log(K.clip(pwm[:, 0, pwm_start:pwm_end, :], K.epsilon(), 1. - K.epsilon()) / K.constant(pwm_background[pwm_start:pwm_end, :])) / K.log(2.0)
        conservation = K.sum(conservation, axis=-1)
        
        mask = K.max(pwm_mask[:, 0, pwm_start:pwm_end, :], axis=-1)
        n_unmasked = K.sum(mask, axis=-1)
        
        mean_conservation = K.sum(conservation * mask, axis=-1) / n_unmasked

        margin_conservation = K.switch(mean_conservation > K.constant(max_bits, shape=(1,)), mean_conservation - K.constant(max_bits, shape=(1,)), K.zeros_like(mean_conservation))
    
        return margin_conservation
    
    return _margin_entropy_ame_masked

def get_target_entropy_sme_masked(pwm_start, pwm_end, pwm_background, target_bits=1.0) :
    
    def _target_entropy_sme_masked(pwm, pwm_mask) :
        conservation = pwm[:, 0, pwm_start:pwm_end, :] * K.log(K.clip(pwm[:, 0, pwm_start:pwm_end, :], K.epsilon(), 1. - K.epsilon()) / K.constant(pwm_background[pwm_start:pwm_end, :])) / K.log(2.0)
        conservation = K.sum(conservation, axis=-1)
        
        mask = K.max(pwm_mask[:, 0, pwm_start:pwm_end, :], axis=-1)
        n_unmasked = K.sum(mask, axis=-1)
        
        mean_conservation = K.sum(conservation * mask, axis=-1) / n_unmasked

        return (mean_conservation - target_bits)**2
    
    return _target_entropy_sme_masked

def get_weighted_loss(loss_coeff=1.) :
    
    def _min_pred(y_true, y_pred) :
        return loss_coeff * y_pred
    
    return _min_pred

def get_mse(loss_coeff=1.) :
    #returns mse function for optimus 
    def _mse(y_true, y_pred):
        return K.mean((y_true - y_pred)**2, axis=-1)
    return _mse

# %%
#Initialize Encoder and Decoder networks
batch_size = 1
seq_length = 50
n_samples = 32
#sample_mode = 'st'
sample_mode = 'gumbel'

norm_mode = 'norm'
max_score_clip = 4.

#Load scrambler
scrambler = load_scrambler_network(seq_length, norm_mode=norm_mode)

#Load sampler
sampler = build_sampler(batch_size, seq_length, n_classes=1, n_samples=n_samples, sample_mode=sample_mode)

# %%
#Load Predictor
predictor_path = 'optimusRetrainedMain.hdf5'

predictor = load_model(predictor_path)

predictor.trainable = False
predictor.compile(optimizer=keras.optimizers.SGD(lr=0.1), loss='mean_squared_error')

# %%
#Build scrambler model
scrambler_class = Input(shape=(1,), name='scrambler_class')
scrambler_input = Input(shape=(1, seq_length, 4), name='scrambler_input')
scrambler_drop = Input(shape=(1, seq_length, 1), name='scrambler_drop')

scrambler_logits, importance_scores = scrambler(scrambler_input, scrambler_drop)

pwm_logits, pwm, sampled_pwm, _, _ = sampler(scrambler_class, scrambler_logits)

scrambler_model = Model([scrambler_input, scrambler_drop, scrambler_class], [pwm_logits, pwm, sampled_pwm, importance_scores])

#Initialize Sequence Templates and Masks
initialize_sequence_templates(scrambler_model, [sequence_template], [x_mean_logits])

scrambler_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss='mean_squared_error'
)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
#Build Auto-scrambler pipeline

#Define model inputs
ae_scrambler_class = Input(shape=(1,), name='ae_scrambler_class')
ae_scrambler_input = Input(shape=(1, seq_length, 4), name='ae_scrambler_input')
ae_scrambler_drop = Input(shape=(1, seq_length, 1), name='ae_scrambler_drop')

#Run encoder and decoder
_, scrambled_pwm, scrambled_sample, pwm_mask, _ = sampler(ae_scrambler_class, scrambler(ae_scrambler_input, ae_scrambler_drop)[0])

#Define layer to deflate sample axis
deflate_scrambled_sample = Lambda(lambda x: K.reshape(x, (batch_size * n_samples, 1, seq_length, 4)), name='deflate_scrambled_sample')

#Deflate sample axis
scrambled_sample_deflated = deflate_scrambled_sample(scrambled_sample)

# %%
def _make_prediction(inputs, predictor=predictor) :
    pred_seq_in = inputs
     
    pred_seq_in_perm = tf.squeeze(pred_seq_in, 1)
    
    outputs = predictor(pred_seq_in_perm)
    
    return outputs

def _make_prediction_scrambled(inputs, predictor=predictor, n_samples=n_samples) :
    pred_seq_in = inputs
     
    pred_seq_in_perm = tf.squeeze(pred_seq_in, 1)
    
    outputs = predictor(pred_seq_in_perm)
    
    return outputs

#Make reference prediction on non-scrambled input sequence
y_pred_non_scrambled = Lambda(_make_prediction, name='make_prediction_non_scrambled')(ae_scrambler_input)

#Make prediction on scrambled sequence samples
y_pred_scrambled_deflated = Lambda(_make_prediction_scrambled, name='make_prediction_scrambled')(scrambled_sample_deflated)

# %%
#Define layer to inflate sample axis
inflate_scrambled_prediction = Lambda(lambda x: K.reshape(x, (batch_size, n_samples)), name='inflate_scrambled_prediction')

#Inflate sample axis
y_pred_scrambled = inflate_scrambled_prediction(y_pred_scrambled_deflated)

#Cost function parameters
pwm_start = 0
pwm_end = 50
max_bits = 0.0

#OPTIMUS: switched to MSE 
mse_loss_func = get_mse()

#Conservation cost
conservation_loss_func = get_target_entropy_sme_masked(pwm_start=pwm_start, pwm_end=pwm_end, pwm_background=x_mean, target_bits=1.8)

#Entropy cost
#entropy_loss_func = get_target_entropy_sme_masked(pwm_start=pwm_start, pwm_end=pwm_end, pwm_background=x_mean, target_bits=target_bits)
entropy_loss_func = get_margin_entropy_ame_masked(pwm_start=pwm_start, pwm_end=pwm_end, pwm_background=x_mean, max_bits=max_bits)

#Define annealing coefficient
anneal_coeff = K.variable(0.0)

#Execute NLL cost
mse_loss = Lambda(lambda x: mse_loss_func(K.tile(x[0], (1, K.shape(x[1])[1])), x[1]), name='mse')([y_pred_non_scrambled, y_pred_scrambled])

#Execute conservation cost
conservation_loss = Lambda(lambda x: anneal_coeff * conservation_loss_func(x[0], x[1]), name='conservation')([scrambled_pwm, pwm_mask])

#Execute entropy cost
entropy_loss = Lambda(lambda x: (1. - anneal_coeff) * entropy_loss_func(x[0], x[1]), name='entropy')([scrambled_pwm, pwm_mask])

loss_model = Model(
    [ae_scrambler_class, ae_scrambler_input, ae_scrambler_drop],
    [mse_loss, conservation_loss, entropy_loss]
)

#Initialize Sequence Templates and Masks
initialize_sequence_templates(loss_model, [sequence_template], [x_mean_logits])

# %%
#Training configuration

#Define experiment suffix (optional)
experiment_suffix = "_example_if_uorf_seqs_per_example_1_start_2_stop"

dataset_name = "egfp_unmod_1"

model_name = "autoscrambler_dataset_" + dataset_name + "_sample_mode_" + sample_mode + "_n_samples_" + str(n_samples) + "_max_bits_" + str(max_bits).replace(".", "") + experiment_suffix

print("Model save name = " + model_name)
# Out:
# Model save name = autoscrambler_dataset_egfp_unmod_1_sample_mode_gumbel_n_samples_32_max_bits_00_example_if_uorf_seqs_per_example_1_start_2_stop

# %%
#(Re-)Initialize scrambler mask

def reset_generator(scrambler_model, verbose=False) :
    session = K.get_session()
    for layer in scrambler_model.layers :
        if 'scrambler' in layer.name :
            for v in layer.__dict__:
                v_arg = getattr(layer, v)
                if hasattr(v_arg,'initializer'):
                    initializer_method = getattr(v_arg, 'initializer')
                    initializer_method.run(session=session)
                    if verbose :
                        print('reinitializing layer {}.{}'.format(layer.name, v))

#(Re-)Initialize Optimizer

def reset_optimizer(opt, verbose=False) :
    session = K.get_session()
    for v in opt.__dict__:
        v_arg = getattr(opt, v)
        if hasattr(v_arg,'initializer'):
            initializer_method = getattr(v_arg, 'initializer')
            initializer_method.run(session=session)
            if verbose :
                print('reinitializing optimizer parameter {}'.format(v))

# %%
#Execute training procedure

class LossHistory(keras.callbacks.Callback) :
    
    def on_train_begin(self, logs={}):
        self.nll_losses = []
        self.entropy_losses = []
        self.conservation_losses = []

    def on_batch_end(self, batch, logs={}) :
        self.nll_losses.append(logs.get('mse_loss'))
        self.entropy_losses.append(logs.get('entropy_loss'))
        self.conservation_losses.append(logs.get('conservation_loss'))

#Define number of training epochs
n_iters = 300

max_n_test = 512

opt = keras.optimizers.Adam(lr=0.01, beta_1=0.5, beta_2=0.9)

loss_model.compile(
    optimizer=opt,
    loss={
        'mse' : get_weighted_loss(loss_coeff=1.0),
        'conservation' : get_weighted_loss(loss_coeff=1.0),
        'entropy' : get_weighted_loss(loss_coeff=5.0)
    }
)

#Reset mask
reset_generator(scrambler_model, verbose=False)
reset_generator(loss_model, verbose=False)
reset_optimizer(opt, verbose=False)

s_test = np.zeros((1, 1))

pwm_test = []
sample_test = []
importance_scores_test = []
train_histories = []

for data_ix in range(min(x_test.shape[0], max_n_test)) :
    
    if data_ix % 100 == 0 :
        print("Optimizing example " + str(data_ix) + "...")
    
    train_history = LossHistory()
    
    # train the autoencoder
    _ = loss_model.fit(
        [s_test, x_test[data_ix:data_ix+1], drop_test[data_ix:data_ix+1]],
        [s_test, s_test, s_test],
        epochs=1,
        steps_per_epoch=n_iters,
        callbacks=[train_history]
    )
    
    _, temp_pwm, temp_sample, temp_importance_scores = scrambler_model.predict_on_batch(x=[x_test[data_ix:data_ix+1], drop_test[data_ix:data_ix+1], s_test])
    
    pwm_test.append(temp_pwm)
    sample_test.append(temp_sample)
    importance_scores_test.append(temp_importance_scores)
    train_histories.append(train_history)
    
    #Reset mask
    reset_generator(scrambler_model)
    reset_generator(loss_model)
    reset_optimizer(opt)

pwm_test = np.concatenate(pwm_test, axis=0)
sample_test = np.concatenate(sample_test, axis=0)
importance_scores_test = np.concatenate(importance_scores_test, axis=0)
# Out:
# Optimizing example 0...
# Epoch 1/1
# 300/300 [==============================] - 7s 23ms/step - loss: 2.8958 - mse_loss: 1.7958 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1000
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7975 - mse_loss: 0.4404 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3570
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.4645 - mse_loss: 2.1617 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3027
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2961 - mse_loss: 0.7070 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5890
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4006 - mse_loss: 1.0142 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3863
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2104 - mse_loss: 0.8254 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3850
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.9486 - mse_loss: 2.3989 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5497
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2008 - mse_loss: 0.6667 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5341
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6933 - mse_loss: 0.4442 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2491
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4441 - mse_loss: 1.0807 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3634
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.4572 - mse_loss: 0.8537 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6034
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9692 - mse_loss: 0.4875 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4817
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7136 - mse_loss: 1.2159 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4978
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9779 - mse_loss: 0.4923 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4857
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4049 - mse_loss: 0.8660 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5389
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9175 - mse_loss: 1.2408 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6767
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8622 - mse_loss: 0.5083 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3539
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6064 - mse_loss: 0.3814 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2250
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6685 - mse_loss: 0.3633 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3052
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3778 - mse_loss: 1.2315 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1463
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.2533 - mse_loss: 0.7397 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5136
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.1937 - mse_loss: 0.6943 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4994
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.1001 - mse_loss: 0.6122 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4879
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7578 - mse_loss: 0.3990 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3588
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7864 - mse_loss: 0.4184 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3680
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2651 - mse_loss: 0.8302 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4349
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.3899 - mse_loss: 0.8868 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5031
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7378 - mse_loss: 0.4465 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2913
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9324 - mse_loss: 0.5379 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3945
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0610 - mse_loss: 0.5784 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4826
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7512 - mse_loss: 1.2640 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4872
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.3035 - mse_loss: 0.8206 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4829
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.8228 - mse_loss: 0.4226 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4002
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.5169 - mse_loss: 2.1195 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3974
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4655 - mse_loss: 1.3281 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1374
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8374 - mse_loss: 0.5041 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3333
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.2861 - mse_loss: 0.8046 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4815
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4567 - mse_loss: 0.6991 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7577
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.0583 - mse_loss: 1.7655 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2928
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3881 - mse_loss: 1.4075 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9806
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5331 - mse_loss: 1.8381 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6949
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0342 - mse_loss: 0.6123 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4218
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.7003 - mse_loss: 1.1232 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5771
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0431 - mse_loss: 0.6374 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4056
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6348 - mse_loss: 1.9985 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6363
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6516 - mse_loss: 1.2112 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4404
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1057 - mse_loss: 0.7035 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4022
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7517 - mse_loss: 0.4008 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3509
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.9587 - mse_loss: 1.8125 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1462
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.1409 - mse_loss: 0.4406 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7003
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1357 - mse_loss: 0.7099 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4257
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1680 - mse_loss: 0.7435 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4246
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1833 - mse_loss: 0.7270 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4563
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8476 - mse_loss: 0.4928 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3548
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6736 - mse_loss: 0.3193 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3542
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2185 - mse_loss: 0.8250 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3935
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.8360 - mse_loss: 1.9074 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9287
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9093 - mse_loss: 0.5479 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3613
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1486 - mse_loss: 0.7121 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4366
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6210 - mse_loss: 0.8825 - conservation_loss: 0.0000e+00 - entropy_loss: 1.7385
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0497 - mse_loss: 0.7202 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3295
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8271 - mse_loss: 0.4874 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3397
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6858 - mse_loss: 1.1226 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5631
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3649 - mse_loss: 0.9676 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3973
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2581 - mse_loss: 0.7414 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5167
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6855 - mse_loss: 0.4217 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2639
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0903 - mse_loss: 0.7027 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3876
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7098 - mse_loss: 0.4971 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2127
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9079 - mse_loss: 0.5426 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3652
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1929 - mse_loss: 0.7548 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4381
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7399 - mse_loss: 0.3970 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3428
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9781 - mse_loss: 0.5396 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4385
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9100 - mse_loss: 1.4025 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5075
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7293 - mse_loss: 0.4599 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2694
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5724 - mse_loss: 1.0967 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4758
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8826 - mse_loss: 0.6728 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2098
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 4.5278 - mse_loss: 3.3660 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1617
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.6759 - mse_loss: 0.4212 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2547
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2591 - mse_loss: 0.8721 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3870
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7469 - mse_loss: 0.4277 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3192
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3418 - mse_loss: 0.7915 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5503
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.1669 - mse_loss: 0.6892 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4777
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5128 - mse_loss: 1.0096 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5032
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0699 - mse_loss: 0.7337 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3362
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9453 - mse_loss: 0.5121 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4332
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9542 - mse_loss: 0.5309 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4232
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1874 - mse_loss: 0.8858 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3015
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6360 - mse_loss: 0.3314 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3045
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7940 - mse_loss: 0.4872 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3067
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.7122 - mse_loss: 1.1202 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5920
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7913 - mse_loss: 0.4068 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3844
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0191 - mse_loss: 0.6114 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4077
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3631 - mse_loss: 0.7068 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6564
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.4418 - mse_loss: 0.9446 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4971
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0202 - mse_loss: 2.4761 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5441
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4714 - mse_loss: 0.8789 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5925
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7495 - mse_loss: 0.4071 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3425
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1743 - mse_loss: 0.6633 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5110
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4779 - mse_loss: 1.1779 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3000
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0172 - mse_loss: 0.4923 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5249
# Optimizing example 100...
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7162 - mse_loss: 0.4306 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2856
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8010 - mse_loss: 0.4611 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3399
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1410 - mse_loss: 0.7193 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4217
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.3081 - mse_loss: 0.8167 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4914
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9481 - mse_loss: 0.6327 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3153
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5935 - mse_loss: 1.5223 - conservation_loss: 0.0000e+00 - entropy_loss: 1.0712
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6546 - mse_loss: 0.3588 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2957
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2473 - mse_loss: 0.7629 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4843
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.8131 - mse_loss: 2.7060 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1071
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1150 - mse_loss: 0.6769 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4381
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4254 - mse_loss: 1.5589 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8666
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5448 - mse_loss: 1.0732 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4716
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3381 - mse_loss: 0.8090 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5291
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1840 - mse_loss: 0.7357 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4484
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7600 - mse_loss: 0.4300 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3299
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1538 - mse_loss: 1.6356 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5182
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9992 - mse_loss: 0.5063 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4928
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3889 - mse_loss: 0.7977 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5912
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8263 - mse_loss: 1.3291 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4971
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.0073 - mse_loss: 0.3094 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6979
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7360 - mse_loss: 0.4329 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3031
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.4151 - mse_loss: 2.2341 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1810
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.8804 - mse_loss: 0.6574 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2230
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 0.9490 - mse_loss: 0.4865 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4625
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9639 - mse_loss: 0.5930 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3709
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6886 - mse_loss: 1.2208 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4678
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.0921 - mse_loss: 0.5994 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4927
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6421 - mse_loss: 1.2945 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3476
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.8118 - mse_loss: 2.1526 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6592
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4591 - mse_loss: 1.5380 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9211
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6832 - mse_loss: 1.0833 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5998
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5190 - mse_loss: 1.0111 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5079
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3191 - mse_loss: 0.8114 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5078
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7410 - mse_loss: 0.6395 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1016
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0076 - mse_loss: 1.4901 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5176
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0941 - mse_loss: 0.7095 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3846
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0917 - mse_loss: 0.6644 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4273
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.4976 - mse_loss: 0.9718 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5258
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.9560 - mse_loss: 2.1525 - conservation_loss: 0.0000e+00 - entropy_loss: 1.8034
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 4.3781 - mse_loss: 3.7694 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6087
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5017 - mse_loss: 1.0038 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4979
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6791 - mse_loss: 0.4255 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2536
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6775 - mse_loss: 1.0572 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6203
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.7545 - mse_loss: 2.1992 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5553
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2261 - mse_loss: 0.8952 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3308
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1491 - mse_loss: 0.7530 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3961
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.8124 - mse_loss: 1.1774 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6350
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2977 - mse_loss: 0.8132 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4845
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9859 - mse_loss: 0.6267 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3592
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6426 - mse_loss: 0.3899 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2526
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 4.3825 - mse_loss: 3.6759 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7066
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.3663 - mse_loss: 0.8525 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5138
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5330 - mse_loss: 1.0927 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4403
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9463 - mse_loss: 0.6115 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3348
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0403 - mse_loss: 2.4720 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5683
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3243 - mse_loss: 0.8632 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4611
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2777 - mse_loss: 0.8227 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4550
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.2192 - mse_loss: 0.7785 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4406
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4672 - mse_loss: 1.5184 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9488
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7660 - mse_loss: 0.5270 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2390
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1341 - mse_loss: 0.7275 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4066
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0271 - mse_loss: 0.6674 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3597
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5789 - mse_loss: 2.0545 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5245
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.6208 - mse_loss: 2.6816 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9391
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1909 - mse_loss: 1.3626 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8283
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5607 - mse_loss: 1.0611 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4996
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6301 - mse_loss: 0.7508 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8793
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.2509 - mse_loss: 0.7204 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5305
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6333 - mse_loss: 1.0632 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5700
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1700 - mse_loss: 0.7445 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4255
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3524 - mse_loss: 0.9282 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4242
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.9248 - mse_loss: 1.4192 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5055
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6143 - mse_loss: 0.9221 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6922
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7241 - mse_loss: 0.5065 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2177
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1262 - mse_loss: 0.6041 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5221
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9445 - mse_loss: 0.5643 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3802
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3113 - mse_loss: 0.8608 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4505
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2137 - mse_loss: 0.6515 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5622
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1082 - mse_loss: 0.6383 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4700
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8311 - mse_loss: 0.5164 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3147
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.3774 - mse_loss: 0.8981 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4794
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8808 - mse_loss: 0.4611 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4197
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.3875 - mse_loss: 2.1904 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1971
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8209 - mse_loss: 0.5010 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3199
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6020 - mse_loss: 0.9589 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6431
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.0040 - mse_loss: 2.4053 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5987
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.1759 - mse_loss: 0.6937 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4823
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 4.2096 - mse_loss: 3.2528 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9568
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9479 - mse_loss: 0.7162 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2318
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.0066 - mse_loss: 0.5285 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4780
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.0939 - mse_loss: 0.4082 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6857
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0672 - mse_loss: 0.8566 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2106
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.9220 - mse_loss: 0.6198 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3022
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5806 - mse_loss: 0.9850 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5956
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5745 - mse_loss: 1.5413 - conservation_loss: 0.0000e+00 - entropy_loss: 1.0332
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1407 - mse_loss: 0.6263 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5144
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 2.3177 - mse_loss: 0.6375 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6802
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 2.0887 - mse_loss: 0.7380 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3506
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 2.3402 - mse_loss: 0.8416 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4986
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 2.3027 - mse_loss: 0.9032 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3995
# Optimizing example 200...
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9723 - mse_loss: 0.6061 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3662
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 4.3032 - mse_loss: 3.3335 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9698
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5369 - mse_loss: 1.1112 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4257
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6204 - mse_loss: 0.3893 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2311
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8989 - mse_loss: 1.3767 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5222
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4634 - mse_loss: 1.5489 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9146
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3336 - mse_loss: 0.7880 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5456
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4331 - mse_loss: 1.4995 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9336
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.0318 - mse_loss: 1.3827 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6492
# Epoch 1/1
# 300/300 [==============================] - 5s 15ms/step - loss: 2.1512 - mse_loss: 0.9305 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2207
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7137 - mse_loss: 0.8845 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8292
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3006 - mse_loss: 1.3659 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9347
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1082 - mse_loss: 0.6670 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4412
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4095 - mse_loss: 0.8833 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5262
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2575 - mse_loss: 1.0764 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1811
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5653 - mse_loss: 1.0414 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5239
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7274 - mse_loss: 0.6378 - conservation_loss: 0.0000e+00 - entropy_loss: 1.0896
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2675 - mse_loss: 1.3612 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9063
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3978 - mse_loss: 1.7295 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6683
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1639 - mse_loss: 0.7694 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3945
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4405 - mse_loss: 1.0099 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4306
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1631 - mse_loss: 0.7804 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3827
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1298 - mse_loss: 0.7277 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4022
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3846 - mse_loss: 1.5866 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7980
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7782 - mse_loss: 1.2503 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5278
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0719 - mse_loss: 0.6240 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4479
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9888 - mse_loss: 0.6360 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3528
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7163 - mse_loss: 0.9441 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7722
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.5267 - mse_loss: 0.9939 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5328
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.7747 - mse_loss: 1.2973 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4774
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9479 - mse_loss: 0.5960 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3518
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8743 - mse_loss: 0.5607 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3137
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6483 - mse_loss: 1.1475 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5008
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5871 - mse_loss: 1.0656 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5216
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7944 - mse_loss: 0.4287 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3657
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.2598 - mse_loss: 0.7037 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5562
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4790 - mse_loss: 1.6265 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8525
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8537 - mse_loss: 0.5096 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3441
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.4672 - mse_loss: 0.9503 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5168
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8691 - mse_loss: 0.4932 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3759
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4598 - mse_loss: 1.5711 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8887
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7986 - mse_loss: 0.5114 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2872
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3506 - mse_loss: 1.4833 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8673
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0204 - mse_loss: 1.5001 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5204
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2992 - mse_loss: 0.7912 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5081
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9315 - mse_loss: 0.6297 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3019
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.4758 - mse_loss: 2.2261 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2497
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.2235 - mse_loss: 2.2029 - conservation_loss: 0.0000e+00 - entropy_loss: 1.0206
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.0786 - mse_loss: 0.5747 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5039
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.8839 - mse_loss: 1.2961 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5878
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3968 - mse_loss: 0.8166 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5802
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0047 - mse_loss: 0.5745 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4302
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.8304 - mse_loss: 1.5555 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2749
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.9159 - mse_loss: 0.5863 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3296
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5781 - mse_loss: 1.5908 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9873
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1188 - mse_loss: 0.7147 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4040
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8080 - mse_loss: 0.4626 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3453
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1334 - mse_loss: 1.5380 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5954
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8891 - mse_loss: 0.4894 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3997
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5929 - mse_loss: 1.2256 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3673
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.8813 - mse_loss: 1.3611 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5202
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1819 - mse_loss: 0.8803 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3016
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6118 - mse_loss: 1.1094 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5024
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6294 - mse_loss: 1.1912 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4381
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7365 - mse_loss: 0.4842 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2523
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1066 - mse_loss: 1.1067 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9999
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.4618 - mse_loss: 0.7772 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6846
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9951 - mse_loss: 1.1172 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8780
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3581 - mse_loss: 0.8899 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4683
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7393 - mse_loss: 0.4109 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3284
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0246 - mse_loss: 1.4431 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5815
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4642 - mse_loss: 0.9227 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5415
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.8738 - mse_loss: 1.6930 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1809
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7179 - mse_loss: 0.3754 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3426
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8802 - mse_loss: 1.0085 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8717
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6786 - mse_loss: 0.3479 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3307
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6327 - mse_loss: 1.1553 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4774
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1370 - mse_loss: 1.2703 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8668
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.1482 - mse_loss: 0.6332 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5150
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.0651 - mse_loss: 0.5609 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5043
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5307 - mse_loss: 0.3135 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2172
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3019 - mse_loss: 0.9066 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3953
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7243 - mse_loss: 0.8799 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8443
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9391 - mse_loss: 0.5539 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3852
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0106 - mse_loss: 0.7509 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2596
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9745 - mse_loss: 1.0787 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8958
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9336 - mse_loss: 0.4318 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5018
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1870 - mse_loss: 0.8331 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3540
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.9624 - mse_loss: 2.5594 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4030
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0648 - mse_loss: 1.4402 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6246
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3929 - mse_loss: 0.8028 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5900
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3418 - mse_loss: 1.4442 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8977
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8211 - mse_loss: 0.6105 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2105
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7811 - mse_loss: 0.5460 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2351
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0071 - mse_loss: 0.5646 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4425
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5992 - mse_loss: 0.3584 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2407
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7778 - mse_loss: 0.4682 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3097
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 1.9612 - mse_loss: 0.5901 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3711
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.1017 - mse_loss: 0.5896 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5121
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6674 - mse_loss: 0.8834 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7840
# Optimizing example 300...
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.6088 - mse_loss: 1.1614 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4473
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1094 - mse_loss: 0.7325 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3769
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6279 - mse_loss: 0.7529 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8750
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9156 - mse_loss: 0.5157 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4000
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9940 - mse_loss: 0.5775 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4165
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.9289 - mse_loss: 1.4289 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5000
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0285 - mse_loss: 0.5417 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4868
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6577 - mse_loss: 1.1080 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5496
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7012 - mse_loss: 0.4143 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2869
# ...
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9506 - mse_loss: 0.7591 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1914
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4543 - mse_loss: 1.0032 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4510
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0330 - mse_loss: 1.5159 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5172
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1042 - mse_loss: 0.5927 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5114
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9109 - mse_loss: 0.6766 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2343
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0988 - mse_loss: 0.7997 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2990
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0003 - mse_loss: 0.5399 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4604
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5704 - mse_loss: 1.7260 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8444
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9220 - mse_loss: 0.5563 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3657
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4835 - mse_loss: 0.9812 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5023
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.3525 - mse_loss: 0.8246 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5279
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.2205 - mse_loss: 1.7040 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5164
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8205 - mse_loss: 0.5409 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2796
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.7920 - mse_loss: 1.2494 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5427
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3738 - mse_loss: 0.8674 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5065
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.0314 - mse_loss: 1.8834 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1480
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0748 - mse_loss: 0.6601 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4147
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.4886 - mse_loss: 1.0644 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4243
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.5892 - mse_loss: 1.0462 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5430
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8319 - mse_loss: 1.2481 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5837
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.3425 - mse_loss: 0.9244 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4182
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.3446 - mse_loss: 0.8515 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4931
# Epoch 1/1
# 300/300 [==============================] - 5s 15ms/step - loss: 2.0328 - mse_loss: 1.3845 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6483
# Epoch 1/1
# 300/300 [==============================] - 4s 15ms/step - loss: 2.3682 - mse_loss: 0.8409 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5273
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.5003 - mse_loss: 1.0226 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4776
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9031 - mse_loss: 0.6393 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2638
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.2706 - mse_loss: 0.7490 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5217
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.9693 - mse_loss: 1.4460 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5233
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.5256 - mse_loss: 1.0282 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4974
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.6340 - mse_loss: 1.0426 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5914
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0568 - mse_loss: 0.5989 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4579
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9254 - mse_loss: 1.0401 - conservation_loss: 0.0000e+00 - entropy_loss: 0.8853
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6467 - mse_loss: 1.5675 - conservation_loss: 0.0000e+00 - entropy_loss: 1.0793
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0010 - mse_loss: 0.6668 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3342
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.6043 - mse_loss: 1.1411 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4633
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.0195 - mse_loss: 0.4923 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5272
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8346 - mse_loss: 0.4892 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3454
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.0430 - mse_loss: 1.4101 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6329
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.1014 - mse_loss: 0.7729 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3285
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.7133 - mse_loss: 1.2277 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4856
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8827 - mse_loss: 0.5147 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3680
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.4270 - mse_loss: 0.8568 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5703
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.9804 - mse_loss: 0.4913 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4891
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.2481 - mse_loss: 0.8426 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4055
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 3.4030 - mse_loss: 2.1615 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2415
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9558 - mse_loss: 0.7642 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1916
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1146 - mse_loss: 0.6071 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5076
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6672 - mse_loss: 0.4970 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1703
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9769 - mse_loss: 0.5499 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4270
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.8900 - mse_loss: 1.2590 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6310
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0445 - mse_loss: 0.7708 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2737
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7278 - mse_loss: 0.3773 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3505
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7800 - mse_loss: 0.4515 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3286
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8292 - mse_loss: 0.5831 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2460
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.3364 - mse_loss: 1.6635 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6729
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.8736 - mse_loss: 0.5147 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3589
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.7241 - mse_loss: 1.2278 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4963
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.8193 - mse_loss: 1.2534 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5659
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4763 - mse_loss: 1.0470 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4293
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.1607 - mse_loss: 0.6596 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5011
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.5162 - mse_loss: 0.9392 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5769
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4975 - mse_loss: 0.9287 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5688
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1432 - mse_loss: 0.9174 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2258
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4131 - mse_loss: 1.2974 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1157
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9348 - mse_loss: 0.6091 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3257
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.5427 - mse_loss: 0.3021 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2407
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0424 - mse_loss: 0.6781 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3644
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5565 - mse_loss: 1.6482 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9083
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4081 - mse_loss: 0.8684 - conservation_loss: 0.0000e+00 - entropy_loss: 1.5397
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.0429 - mse_loss: 0.6492 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3936
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 2.7039 - mse_loss: 1.1026 - conservation_loss: 0.0000e+00 - entropy_loss: 1.6013
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.1235 - mse_loss: 0.6600 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4635
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.2524 - mse_loss: 0.7324 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5200
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9409 - mse_loss: 0.6809 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2600
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.7062 - mse_loss: 2.7622 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9439
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6760 - mse_loss: 0.3471 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3288
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.5049 - mse_loss: 1.0956 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4093
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 0.9699 - mse_loss: 0.4845 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4854
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 0.8563 - mse_loss: 0.3816 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4747
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0223 - mse_loss: 0.6106 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4117
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.3574 - mse_loss: 0.8494 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5079
# Epoch 1/1
# 300/300 [==============================] - 4s 14ms/step - loss: 1.5783 - mse_loss: 1.0990 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4793
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6715 - mse_loss: 0.4435 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2279
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0025 - mse_loss: 0.5977 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4048
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.4904 - mse_loss: 1.0672 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4232
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 3.4256 - mse_loss: 2.0499 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3758
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.0652 - mse_loss: 0.5917 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4735
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6370 - mse_loss: 0.3777 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2593
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.1972 - mse_loss: 0.7822 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4150
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 0.9190 - mse_loss: 0.4485 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4704
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9088 - mse_loss: 1.3152 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5936
# Optimizing example 500...
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.7580 - mse_loss: 1.0093 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7487
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 2.0959 - mse_loss: 0.6679 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4280
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.9290 - mse_loss: 0.6605 - conservation_loss: 0.0000e+00 - entropy_loss: 1.2684
# Epoch 1/1
# 300/300 [==============================] - 4s 13ms/step - loss: 1.6458 - mse_loss: 1.0668 - conservation_loss: 0.0000e+00 - entropy_loss: 0.5790
# Epoch 1/1
# 300/300 [==============================] - 3s 10ms/step - loss: 1.1774 - mse_loss: 0.5373 - conservation_loss: 0.0000e+00 - entropy_loss: 0.6401
# Epoch 1/1
# 300/300 [==============================] - 3s 11ms/step - loss: 3.2026 - mse_loss: 2.0541 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1484
# Epoch 1/1
# 300/300 [==============================] - 3s 11ms/step - loss: 1.8184 - mse_loss: 0.4553 - conservation_loss: 0.0000e+00 - entropy_loss: 1.3630
# Epoch 1/1
# 300/300 [==============================] - 3s 11ms/step - loss: 1.2729 - mse_loss: 0.7940 - conservation_loss: 0.0000e+00 - entropy_loss: 0.4789
# Epoch 1/1
# 300/300 [==============================] - 3s 12ms/step - loss: 1.6625 - mse_loss: 0.4641 - conservation_loss: 0.0000e+00 - entropy_loss: 1.1984
# Epoch 1/1
# 300/300 [==============================] - 3s 10ms/step - loss: 2.4948 - mse_loss: 1.0761 - conservation_loss: 0.0000e+00 - entropy_loss: 1.4187
# Epoch 1/1
# 300/300 [==============================] - 3s 9ms/step - loss: 1.5528 - mse_loss: 0.7774 - conservation_loss: 0.0000e+00 - entropy_loss: 0.7754
# Epoch 1/1
# 300/300 [==============================] - 3s 9ms/step - loss: 2.6447 - mse_loss: 1.7289 - conservation_loss: 0.0000e+00 - entropy_loss: 0.9159

# %%
#Argmax the gumbel sequence samples

sample_test_argmax = np.argmax(sample_test, axis=-1)
sample_test_discrete = np.zeros(sample_test.shape)
for i in range(sample_test_discrete.shape[0]) :
    for j in range(sample_test_discrete.shape[1]) :
        for k in range(sample_test_discrete.shape[3]) :
            sample_test_discrete[i, j, 0, k, sample_test_argmax[i, j, 0, k]] = 1.

# %%
#Calculate original and scrambled predictions

y_test_hats = []
y_test_hats_scrambled = []
for i in range(min(x_test.shape[0], max_n_test)) :
    
    y_test_hat_ref = predictor.predict(x=[np.expand_dims(x_test[i, 0, :, :], axis=0)], batch_size=1)[0, 0]
    y_test_hat = np.mean(predictor.predict(x=[sample_test_discrete[i, :, 0, :, :]], batch_size=32)[:, 0])
    
    y_test_hats.append(y_test_hat_ref)
    y_test_hats_scrambled.append(y_test_hat)

y_test_hat = np.array(y_test_hats)
y_test_hat_scrambled = np.array(y_test_hats_scrambled)

y_test_mse = np.mean((y_test_hat - y_test_hat_scrambled)**2)

print("Mean MSE = " + str(y_test_mse))
# Out:
# Mean MSE = 0.16070575

# %%
#Calculate entropies (pre-trained model)

kl_divs = np.sum(pwm_test[:max_n_test, 0, ...] * np.log(pwm_test[:max_n_test, 0, ...] / np.tile(np.expand_dims(x_mean, axis=0), (min(x_test.shape[0], max_n_test), 1, 1))), axis=-1) / np.log(2.0)

x_mean_kl_divs = np.sum(kl_divs * sequence_mask, axis=-1) / np.sum(sequence_mask)
x_mean_kl_div = np.mean(x_mean_kl_divs)
x_median_kl_div = np.median(x_mean_kl_divs)

print("Mean KL Div against background (bits) = " + str(x_mean_kl_div))
print("Median KL Div against background (bits) = " + str(x_median_kl_div))
# Out:
# Mean KL Div against background (bits) = 0.18102452787123635
# Median KL Div against background (bits) = 0.22952604113112085

# %%
import seaborn as sns

f = plt.figure(figsize=(6, 4))

sns.swarmplot(data=[x_mean_kl_divs])

plt.tight_layout()

plt.show()

# %%
from scipy.stats import pearsonr

save_figs = True

r_val, _ = pearsonr(y_test_hat, y_test_hat_scrambled)

f = plt.figure(figsize=(4, 4))

plt.scatter(y_test_hat, y_test_hat_scrambled, color='black', s=5, alpha=0.75)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel("Original Prediction", fontsize=14)
plt.ylabel("Scrambled Prediction", fontsize=14)

plt.title("R^2 = " + str(round(r_val**2, 2)), fontsize=14)

plt.tight_layout()

fig_name = model_name[model_name.find("max_bits"):]

if save_figs :
    plt.savefig("from_scratch_scrambler_1_start_2_stop_" + fig_name + "_test_scatter.png", transparent=True, dpi=300)
    plt.savefig("from_scratch_scrambler_1_start_2_stop_" + fig_name + "_test_scatter.eps")

plt.show()

# %%
#Load held-out predictor
gt_predictor_path = 'retrained_main_MRL_model.hdf5'

gt_predictor = load_model(gt_predictor_path)

gt_predictor.trainable = False
gt_predictor.compile(optimizer=keras.optimizers.SGD(lr=0.1), loss='mean_squared_error')

# %%
#Calculate original and scrambled predictions

y_test_hats = []
y_test_hats_scrambled = []
for i in range(min(x_test.shape[0], max_n_test)) :
    
    y_test_hat_ref = gt_predictor.predict(x=[np.expand_dims(x_test[i, 0, :, :], axis=0)], batch_size=1)[0, 0]
    y_test_hat = np.mean(gt_predictor.predict(x=[sample_test_discrete[i, :, 0, :, :]], batch_size=32)[:, 0])
    
    y_test_hats.append(y_test_hat_ref)
    y_test_hats_scrambled.append(y_test_hat)

y_test_hat = np.array(y_test_hats)
y_test_hat_scrambled = np.array(y_test_hats_scrambled)

y_test_mse = np.mean((y_test_hat - y_test_hat_scrambled)**2)

print("Mean MSE = " + str(y_test_mse))
# Out:
# Mean MSE = 0.1752406

# %%
from scipy.stats import pearsonr

save_figs = True

r_val, _ = pearsonr(y_test_hat, y_test_hat_scrambled)

f = plt.figure(figsize=(4, 4))

plt.scatter(y_test_hat, y_test_hat_scrambled, color='black', s=5, alpha=0.75)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel("Original Prediction", fontsize=14)
plt.ylabel("Scrambled Prediction", fontsize=14)

plt.title("R^2 = " + str(round(r_val**2, 2)), fontsize=14)

plt.tight_layout()

fig_name = model_name[model_name.find("max_bits"):]

if save_figs :
    plt.savefig("from_scratch_scrambler_1_start_2_stop_" + fig_name + "_test_scatter_gt.png", transparent=True, dpi=300)
    plt.savefig("from_scratch_scrambler_1_start_2_stop_" + fig_name + "_test_scatter_gt.eps")

plt.show()

# %%
#Cache importance scores

short_name = model_name[model_name.find("max_bits"):]
#np.save("from_scratch_scrambler_1_start_2_stop_" + short_name + "_importance_scores_test", importance_scores_test)
importance_scores_test = np.load("from_scratch_scrambler_1_start_2_stop_" + short_name + "_importance_scores_test.npy")

# %%
#Benchmark logic reconstruction accuracy

def totalUTR(utrDummy):
    return 'GGGACATCGTAGAGAGTCGTACTTA' + utrDummy

#adding masks of A for start and X for stops to premade datasets as strings to do Johanne's second comparison method 
def maskTomask(utr):
    #modified UTR dissection code ot turn masks into strings execute Johanne's scripts 
    # create masks for if uaug, oof uaug, if stop, oof stop
    fullUTR = totalUTR(utr)
    stops = ['TAA', 'TGA', 'TAG']
    ifuaug_mask = [0] * len(fullUTR)
    oofuaug_mask = [0] * len(fullUTR)
    ifstop_mask = [0] * len(fullUTR)
    oofstop_mask = [0] * len(fullUTR)
    for i in range(0, len(fullUTR) - 2):
        codon = fullUTR[i : i + 3]
        frame = i % 3
        if frame == 0:
            # check start or stop
            if codon == "ATG":
                ifuaug_mask[i] = 1
                ifuaug_mask[i + 1] = 1
                ifuaug_mask[i + 2] = 1
            if codon in stops:
                ifstop_mask[i] = 1
                ifstop_mask[i + 1] = 1
                ifstop_mask[i + 2] = 1
        else:
            if codon == "ATG":
                oofuaug_mask[i] = 1
                oofuaug_mask[i + 1] = 1
                oofuaug_mask[i + 2] = 1
            if codon in stops:
                oofstop_mask[i] = 1
                oofstop_mask[i + 1] = 1
                oofstop_mask[i + 2] = 1
    # trim off the first part which is constant
    #trim and sum? 
    ifstart = ifuaug_mask[25:]
    ifstops = ifstop_mask[25:]
    #print (oofuaug_mask[25:])
    #print (oofstop_mask[25:])
    #turn if stops to masks
    baseString = ["N"] * 50
    for i in range(0, 50):
        if ifstart[i] == 1:
            baseString[i] = "A"
        if ifstops[i] == 1:
            baseString[i] = "X"
    finalString = "".join(baseString)
    return finalString

def calcNANDReconstructionAccuracy(scores_test, y_test, nts = 6, start_cover_min = 3, stop_cover_min = 3):
    #Calculate NAND reconstruction accuracy
    accs = []
    importance_scores_test = scores_test
    #print (scores_test.shape)
    #print (y_test.shape)
    yep = 0
    nope = 0
    for i in range(x_test.shape[0]) :

        plot_i = i
        
        
        #if i <= 3:
            #plot_dna_logo(x_test[plot_i, 0, :, :], sequence_template=sequence_template, figsize=(10, 1), plot_start=0, plot_end=50)
            #plot_importance_scores(importance_scores_test[plot_i, 0, :, :].T, encoder.decode(x_test[plot_i, 0, :, :]), figsize=(10, 1), score_clip=score_clip, sequence_template=sequence_template, plot_start=0, plot_end=50)

        on = np.squeeze(scores_test[i, :])
        #print (on)
        top_ix = np.argsort(on)[::-1][:nts]
        #print (top_ix)
        #print (top_ix)
        #Start A
        #print (y_test[i, top_ix, 1])
        start_cover_a = np.sum(y_test[i, top_ix, 1])

        #Stop X
        #print (y_test[i, top_ix, 4])
        stop_cover_x = np.sum(y_test[i, top_ix, 4])

        if (start_cover_a >= start_cover_min) and (stop_cover_x >= stop_cover_min):
            accs.append(1.)
            yep += 1
            #print ("yes")
        else :
            #print ("no")
            accs.append(0.)
            nope += 1
        #input()

    accs = np.array(accs)
    print ("Recovered: ", yep)
    print ("Not Recovered: ", nope)
    print("Logic Function Reconstruction Accuracy = " + str(round(np.mean(accs), 3)))
    return np.mean(accs)

def one_hot_encode_gt(df, col='gt', seq_len=50):
    # Dictionary returning one-hot encoding of nucleotides. 
    nuc_d = {'n':[1,0,0,0,0,0,0],'a':[0,1,0,0,0,0,0],'b':[0,0,1,0,0,0,0],'c':[0,0,0,1,0,0,0],'x':[0,0,0,0,1,0,0],'y':[0,0,0,0,0,1,0],'z':[0,0,0,0,0,0,1]}
    
    # Creat empty matrix.
    vectors=np.empty([len(df),seq_len,7])
    
    # Iterate through UTRs and one-hot encode
    for i,seq in enumerate(df[col].str[:seq_len]): 
        seq = seq.lower()
        a = np.array([nuc_d[x] for x in seq])
        vectors[i] = a
    return vectors

gt_test = one_hot_encode_gt(e_test)

print("From scratch:")

_ = calcNANDReconstructionAccuracy(importance_scores_test, gt_test, nts=6, start_cover_min=3, stop_cover_min=3)
# Out:
# From scratch:
# Recovered:  316
# Not Recovered:  196
# Logic Function Reconstruction Accuracy = 0.617
